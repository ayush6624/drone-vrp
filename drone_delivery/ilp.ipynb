# %%
import pulp
import matplotlib.pyplot as plot
import networkx as nx
import math

def dist(x1, y1, x2, y2):
    return math.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)

def get_graph(coordinates):
    g = nx.Graph()
    n = len(coordinates)
    for i in range(n):
        for j in range(i + 1):
            g.add_edge(i, j, weight=dist(coordinates[i][0], coordinates[i][1], coordinates[j][0], coordinates[j][1]))
    nx.draw(g, with_labels=1)
    plot.show()
    return g

def plot_cycle(coordinates, cycle):
    x_coordinates = [coordinates[i][0] for i in cycle]
    y_coordinates = [coordinates[i][1] for i in cycle]

    # Add the first vertex of the cycle (to close the cycle)
    x_coordinates.append(coordinates[cycle[0]][0])
    y_coordinates.append(coordinates[cycle[0]][1])

    plot.plot(x_coordinates, y_coordinates, 'xb-', )
    plot.show()

# %%
# No need to do NN algorithm for now

# %%
def ilp(g):
    n = g.number_of_nodes()
    m = pulp.LpProblem('TSP', pulp.LpMinimize)
    x= []
    # be careful converting list comprehension to for loops
    for i in range(n):
        y = []
        for j in range(n):
            y.append(pulp.LpVariable("x_{}_{}".format(j,i), cat='Binary')) # These are edges. Deliberate (j, i) Category of 'binary' means 'ON' & 'OFF', will be taken only if its == 1
        x.append(y)

    for i in range(n): # Never take self-loops (an edge from i to i).
        m += pulp.lpSum(x[i][i]) == 0
    
    for i in range(n): # Make sure the self-loops areof weight 0
      g.add_edge(i, i, weight =0)
    
    # The objective function (to be minimized) is the sum of the weights of taken edges
    m += pulp.lpSum([g[i][j]['weight'] * x[i][j] for i in range(n) for j in range(n)])

    # Add the constraints saying that each vertex has exactly one outgoing edge.
    for i in range(n):
        m += pulp.lpSum([x[i][j] for j in range(n)]) == 1

    # Add the constraints saying that each vertex has exactly one incoming edge.
    for i in range(n):
        m += pulp.lpSum([x[j][i] for j in range(n)]) == 1

    # Introduce auxiliary variables u_i for 0 <= i <= n-1.
    u = []
    # u_0 = 0
    u.append(pulp.LpVariable('u_0', 1, 1, cat='Integer'))
    # For i > 0, we have that 2 <= u_i <= n.
    for i in range(1, n):
        u.append(pulp.LpVariable('u_' + str(i), 2, n, cat='Integer'))

    # In order to ensure that we find *one* cycle covering all vertices,
    # for every i, j > 0, we add the constraint u_i - u_j + n * x_i_j <= n-1
    for i in range(1, n):
        for j in range(1, n):
            m += pulp.lpSum([u[i] - u[j] + n * x[i][j]]) <= n - 1
    print(m)
    m.solve()
    # pulp.value(x[i][j]) has 0, 1 values, where 1 is the edge taken!

    weight = sum([g[i][j]['weight'] * pulp.value(x[i][j]) for i in range(n) for j in range(n)])
    print("the minimal cycle length is ", weight)
    
    # Extract cycle from the matrix x
    cycleMatrix = [[pulp.value(x[i][j]) for i in range(n)] for j in range(n)]
    i = 0
    i = cycleMatrix[0].index(1)
    cycle = [i]
    while (i != 0):
        i = cycleMatrix[i].index(1)
        cycle.append(i)
    return cycle

# %%
coordinates = [(0, 0), (3, 0), (0, 4)]
g = get_graph(coordinates)
cycle = ilp(g)
plot_cycle(coordinates, cycle)
# Out:
# TSP:
# MINIMIZE
# 3.0*x_0_1 + 4.0*x_0_2 + 3.0*x_1_0 + 5.0*x_1_2 + 4.0*x_2_0 + 5.0*x_2_1 + 0.0
# SUBJECT TO
# _C1: x_0_0 = 0
#
# _C2: x_1_1 = 0
#
# _C3: x_2_2 = 0
#
# _C4: x_0_0 + x_1_0 + x_2_0 = 1
#
# _C5: x_0_1 + x_1_1 + x_2_1 = 1
#
# _C6: x_0_2 + x_1_2 + x_2_2 = 1
#
# _C7: x_0_0 + x_0_1 + x_0_2 = 1
#
# _C8: x_1_0 + x_1_1 + x_1_2 = 1
#
# _C9: x_2_0 + x_2_1 + x_2_2 = 1
#
# _C10: 0 u_1 + 3 x_1_1 <= 2
#
# _C11: u_1 - u_2 + 3 x_2_1 <= 2
#
# _C12: - u_1 + u_2 + 3 x_1_2 <= 2
#
# _C13: 0 u_2 + 3 x_2_2 <= 2
#
# VARIABLES
# 2 <= u_1 <= 3 Integer
# 2 <= u_2 <= 3 Integer
# 0 <= x_0_0 <= 1 Integer
# 0 <= x_0_1 <= 1 Integer
# 0 <= x_0_2 <= 1 Integer
# 0 <= x_1_0 <= 1 Integer
# 0 <= x_1_1 <= 1 Integer
# 0 <= x_1_2 <= 1 Integer
# 0 <= x_2_0 <= 1 Integer
# 0 <= x_2_1 <= 1 Integer
# 0 <= x_2_2 <= 1 Integer
#
# the minimal cycle length is  12.0

# %%
# Example 2
# Consider the following 8 points.
coordinates = [(162, 137), (122, 177), (249, 49), (37, 127), (13, 277), (164, 293), (270, 42), (135, 123)]
# Create a corresponding graph.
g = get_graph(coordinates)
# Compute an optimal Hamiltonian path using Integer Linear Programming:
cycle = ilp(g)
# Plot the resulting cycle
plot_cycle(coordinates, cycle)
# Out:
# TSP:
# MINIMIZE
# 56.568542494923804*x_0_1 + 123.7457069962429*x_0_2 + 125.39936203984452*x_0_3 + 204.45292856792244*x_0_4 + 156.01281998605114*x_0_5 + 143.83671297690307*x_0_6 + 30.4138126514911*x_0_7 + 56.568542494923804*x_1_0 + 180.31361568112376*x_1_2 + 98.6154146165801*x_1_3 + 147.92227688891217*x_1_4 + 123.36936410632909*x_1_5 + 200.32224040280698*x_1_6 + 55.54277630799526*x_1_7 + 123.7457069962429*x_2_0 + 180.31361568112376*x_2_1 + 225.89378034819816*x_2_3 + 328.1463088318989*x_2_4 + 258.3815008858026*x_2_5 + 22.135943621178654*x_2_6 + 135.91173606425605*x_2_7 + 125.39936203984452*x_3_0 + 98.6154146165801*x_3_1 + 225.89378034819816*x_3_2 + 151.90786681406595*x_3_4 + 209.0095691589263*x_3_5 + 248.02016047087784*x_3_6 + 98.08159868191383*x_3_7 + 204.45292856792244*x_4_0 + 147.92227688891217*x_4_1 + 328.1463088318989*x_4_2 + 151.90786681406595*x_4_3 + 151.8453160291749*x_4_5 + 348.24416721604973*x_4_6 + 196.468827043885*x_4_7 + 156.01281998605114*x_5_0 + 123.36936410632909*x_5_1 + 258.3815008858026*x_5_2 + 209.0095691589263*x_5_3 + 151.8453160291749*x_5_4 + 272.4646766096479*x_5_6 + 172.45579143653018*x_5_7 + 143.83671297690307*x_6_0 + 200.32224040280698*x_6_1 + 22.135943621178654*x_6_2 + 248.02016047087784*x_6_3 + 348.24416721604973*x_6_4 + 272.4646766096479*x_6_5 + 157.4357011608231*x_6_7 + 30.4138126514911*x_7_0 + 55.54277630799526*x_7_1 + 135.91173606425605*x_7_2 + 98.08159868191383*x_7_3 + 196.468827043885*x_7_4 + 172.45579143653018*x_7_5 + 157.4357011608231*x_7_6 + 0.0
# SUBJECT TO
# _C1: x_0_0 = 0
#
# _C2: x_1_1 = 0
#
# _C3: x_2_2 = 0
#
# _C4: x_3_3 = 0
#
# _C5: x_4_4 = 0
#
# _C6: x_5_5 = 0
#
# _C7: x_6_6 = 0
#
# _C8: x_7_7 = 0
#
# _C9: x_0_0 + x_1_0 + x_2_0 + x_3_0 + x_4_0 + x_5_0 + x_6_0 + x_7_0 = 1
#
# _C10: x_0_1 + x_1_1 + x_2_1 + x_3_1 + x_4_1 + x_5_1 + x_6_1 + x_7_1 = 1
#
# _C11: x_0_2 + x_1_2 + x_2_2 + x_3_2 + x_4_2 + x_5_2 + x_6_2 + x_7_2 = 1
#
# _C12: x_0_3 + x_1_3 + x_2_3 + x_3_3 + x_4_3 + x_5_3 + x_6_3 + x_7_3 = 1
#
# _C13: x_0_4 + x_1_4 + x_2_4 + x_3_4 + x_4_4 + x_5_4 + x_6_4 + x_7_4 = 1
#
# _C14: x_0_5 + x_1_5 + x_2_5 + x_3_5 + x_4_5 + x_5_5 + x_6_5 + x_7_5 = 1
#
# _C15: x_0_6 + x_1_6 + x_2_6 + x_3_6 + x_4_6 + x_5_6 + x_6_6 + x_7_6 = 1
#
# _C16: x_0_7 + x_1_7 + x_2_7 + x_3_7 + x_4_7 + x_5_7 + x_6_7 + x_7_7 = 1
#
# _C17: x_0_0 + x_0_1 + x_0_2 + x_0_3 + x_0_4 + x_0_5 + x_0_6 + x_0_7 = 1
#
# _C18: x_1_0 + x_1_1 + x_1_2 + x_1_3 + x_1_4 + x_1_5 + x_1_6 + x_1_7 = 1
#
# _C19: x_2_0 + x_2_1 + x_2_2 + x_2_3 + x_2_4 + x_2_5 + x_2_6 + x_2_7 = 1
#
# _C20: x_3_0 + x_3_1 + x_3_2 + x_3_3 + x_3_4 + x_3_5 + x_3_6 + x_3_7 = 1
#
# _C21: x_4_0 + x_4_1 + x_4_2 + x_4_3 + x_4_4 + x_4_5 + x_4_6 + x_4_7 = 1
#
# _C22: x_5_0 + x_5_1 + x_5_2 + x_5_3 + x_5_4 + x_5_5 + x_5_6 + x_5_7 = 1
#
# _C23: x_6_0 + x_6_1 + x_6_2 + x_6_3 + x_6_4 + x_6_5 + x_6_6 + x_6_7 = 1
#
# _C24: x_7_0 + x_7_1 + x_7_2 + x_7_3 + x_7_4 + x_7_5 + x_7_6 + x_7_7 = 1
#
# _C25: 0 u_1 + 8 x_1_1 <= 7
#
# _C26: u_1 - u_2 + 8 x_2_1 <= 7
#
# _C27: u_1 - u_3 + 8 x_3_1 <= 7
#
# _C28: u_1 - u_4 + 8 x_4_1 <= 7
#
# _C29: u_1 - u_5 + 8 x_5_1 <= 7
#
# _C30: u_1 - u_6 + 8 x_6_1 <= 7
#
# _C31: u_1 - u_7 + 8 x_7_1 <= 7
#
# _C32: - u_1 + u_2 + 8 x_1_2 <= 7
#
# _C33: 0 u_2 + 8 x_2_2 <= 7
#
# _C34: u_2 - u_3 + 8 x_3_2 <= 7
#
# _C35: u_2 - u_4 + 8 x_4_2 <= 7
#
# _C36: u_2 - u_5 + 8 x_5_2 <= 7
#
# _C37: u_2 - u_6 + 8 x_6_2 <= 7
#
# _C38: u_2 - u_7 + 8 x_7_2 <= 7
#
# _C39: - u_1 + u_3 + 8 x_1_3 <= 7
#
# _C40: - u_2 + u_3 + 8 x_2_3 <= 7
#
# _C41: 0 u_3 + 8 x_3_3 <= 7
#
# _C42: u_3 - u_4 + 8 x_4_3 <= 7
#
# _C43: u_3 - u_5 + 8 x_5_3 <= 7
#
# _C44: u_3 - u_6 + 8 x_6_3 <= 7
#
# _C45: u_3 - u_7 + 8 x_7_3 <= 7
#
# _C46: - u_1 + u_4 + 8 x_1_4 <= 7
#
# _C47: - u_2 + u_4 + 8 x_2_4 <= 7
#
# _C48: - u_3 + u_4 + 8 x_3_4 <= 7
#
# _C49: 0 u_4 + 8 x_4_4 <= 7
#
# _C50: u_4 - u_5 + 8 x_5_4 <= 7
#
# _C51: u_4 - u_6 + 8 x_6_4 <= 7
#
# _C52: u_4 - u_7 + 8 x_7_4 <= 7
#
# _C53: - u_1 + u_5 + 8 x_1_5 <= 7
#
# _C54: - u_2 + u_5 + 8 x_2_5 <= 7
#
# _C55: - u_3 + u_5 + 8 x_3_5 <= 7
#
# _C56: - u_4 + u_5 + 8 x_4_5 <= 7
#
# _C57: 0 u_5 + 8 x_5_5 <= 7
#
# _C58: u_5 - u_6 + 8 x_6_5 <= 7
#
# _C59: u_5 - u_7 + 8 x_7_5 <= 7
#
# _C60: - u_1 + u_6 + 8 x_1_6 <= 7
#
# _C61: - u_2 + u_6 + 8 x_2_6 <= 7
#
# _C62: - u_3 + u_6 + 8 x_3_6 <= 7
#
# _C63: - u_4 + u_6 + 8 x_4_6 <= 7
#
# _C64: - u_5 + u_6 + 8 x_5_6 <= 7
#
# _C65: 0 u_6 + 8 x_6_6 <= 7
#
# _C66: u_6 - u_7 + 8 x_7_6 <= 7
#
# _C67: - u_1 + u_7 + 8 x_1_7 <= 7
#
# _C68: - u_2 + u_7 + 8 x_2_7 <= 7
#
# _C69: - u_3 + u_7 + 8 x_3_7 <= 7
#
# _C70: - u_4 + u_7 + 8 x_4_7 <= 7
#
# _C71: - u_5 + u_7 + 8 x_5_7 <= 7
#
# _C72: - u_6 + u_7 + 8 x_6_7 <= 7
#
# _C73: 0 u_7 + 8 x_7_7 <= 7
#
# VARIABLES
# 2 <= u_1 <= 8 Integer
# 2 <= u_2 <= 8 Integer
# 2 <= u_3 <= 8 Integer
# 2 <= u_4 <= 8 Integer
# 2 <= u_5 <= 8 Integer
# 2 <= u_6 <= 8 Integer
# 2 <= u_7 <= 8 Integer
# 0 <= x_0_0 <= 1 Integer
# 0 <= x_0_1 <= 1 Integer
# 0 <= x_0_2 <= 1 Integer
# 0 <= x_0_3 <= 1 Integer
# 0 <= x_0_4 <= 1 Integer
# 0 <= x_0_5 <= 1 Integer
# 0 <= x_0_6 <= 1 Integer
# 0 <= x_0_7 <= 1 Integer
# 0 <= x_1_0 <= 1 Integer
# 0 <= x_1_1 <= 1 Integer
# 0 <= x_1_2 <= 1 Integer
# 0 <= x_1_3 <= 1 Integer
# 0 <= x_1_4 <= 1 Integer
# 0 <= x_1_5 <= 1 Integer
# 0 <= x_1_6 <= 1 Integer
# 0 <= x_1_7 <= 1 Integer
# 0 <= x_2_0 <= 1 Integer
# 0 <= x_2_1 <= 1 Integer
# 0 <= x_2_2 <= 1 Integer
# 0 <= x_2_3 <= 1 Integer
# 0 <= x_2_4 <= 1 Integer
# 0 <= x_2_5 <= 1 Integer
# 0 <= x_2_6 <= 1 Integer
# 0 <= x_2_7 <= 1 Integer
# 0 <= x_3_0 <= 1 Integer
# 0 <= x_3_1 <= 1 Integer
# 0 <= x_3_2 <= 1 Integer
# 0 <= x_3_3 <= 1 Integer
# 0 <= x_3_4 <= 1 Integer
# 0 <= x_3_5 <= 1 Integer
# 0 <= x_3_6 <= 1 Integer
# 0 <= x_3_7 <= 1 Integer
# 0 <= x_4_0 <= 1 Integer
# 0 <= x_4_1 <= 1 Integer
# 0 <= x_4_2 <= 1 Integer
# 0 <= x_4_3 <= 1 Integer
# 0 <= x_4_4 <= 1 Integer
# 0 <= x_4_5 <= 1 Integer
# 0 <= x_4_6 <= 1 Integer
# 0 <= x_4_7 <= 1 Integer
# 0 <= x_5_0 <= 1 Integer
# 0 <= x_5_1 <= 1 Integer
# 0 <= x_5_2 <= 1 Integer
# 0 <= x_5_3 <= 1 Integer
# 0 <= x_5_4 <= 1 Integer
# 0 <= x_5_5 <= 1 Integer
# 0 <= x_5_6 <= 1 Integer
# 0 <= x_5_7 <= 1 Integer
# 0 <= x_6_0 <= 1 Integer
# 0 <= x_6_1 <= 1 Integer
# 0 <= x_6_2 <= 1 Integer
# 0 <= x_6_3 <= 1 Integer
# 0 <= x_6_4 <= 1 Integer
# 0 <= x_6_5 <= 1 Integer
# 0 <= x_6_6 <= 1 Integer
# 0 <= x_6_7 <= 1 Integer
# 0 <= x_7_0 <= 1 Integer
# 0 <= x_7_1 <= 1 Integer
# 0 <= x_7_2 <= 1 Integer
# 0 <= x_7_3 <= 1 Integer
# 0 <= x_7_4 <= 1 Integer
# 0 <= x_7_5 <= 1 Integer
# 0 <= x_7_6 <= 1 Integer
# 0 <= x_7_7 <= 1 Integer
#
# the minimal cycle length is  883.6570807887454

# %%
# Example 3
# Consider the following 10 points.
coordinates = [(88, 106), (248, 67), (251, 24), (124, 221), (136, 148), (262, 88), (179, 45), (60, 188), (272, 99), (30, 107)]
# Create a corresponding graph.
g = get_graph(coordinates)
# Compute an optimal Hamiltonian path using Integer Linear Programming:
cycle = ilp(g)
print(cycle)
# Plot the resulting cycle
plot_cycle(coordinates, cycle)
# Out:
# TSP:
# MINIMIZE
# 164.68454693747074*x_0_1 + 182.4636950190366*x_0_2 + 120.50311199301038*x_0_3 + 63.7808748764079*x_0_4 + 174.92855684535903*x_0_5 + 109.55363982999378*x_0_6 + 86.64871608973787*x_0_7 + 184.13310403075272*x_0_8 + 58.008620049092706*x_0_9 + 164.68454693747074*x_1_0 + 43.104524124504614*x_1_2 + 197.71696942852427*x_1_3 + 138.2208377922808*x_1_4 + 25.238858928247925*x_1_5 + 72.42237223399962*x_1_6 + 223.57325421436258*x_1_7 + 40.0*x_1_8 + 221.63934668736056*x_1_9 + 182.4636950190366*x_2_0 + 43.104524124504614*x_2_1 + 234.3885662740399*x_2_3 + 169.11830178901394*x_2_4 + 64.93843238021688*x_2_5 + 75.0*x_2_6 + 251.7478897627545*x_2_7 + 77.88452991448301*x_2_8 + 236.07202290826416*x_2_9 + 120.50311199301038*x_3_0 + 197.71696942852427*x_3_1 + 234.3885662740399*x_3_2 + 73.97972695272672*x_3_4 + 191.65855055279948*x_3_5 + 184.39360075664231*x_3_6 + 72.00694410957877*x_3_7 + 191.80198122021577*x_3_8 + 147.75655653811103*x_3_9 + 63.7808748764079*x_4_0 + 138.2208377922808*x_4_1 + 169.11830178901394*x_4_2 + 73.97972695272672*x_4_3 + 139.5564401953561*x_4_5 + 111.61541112229978*x_4_6 + 85.88364221433555*x_4_7 + 144.55794685869054*x_4_8 + 113.65298060323803*x_4_9 + 174.92855684535903*x_5_0 + 25.238858928247925*x_5_1 + 64.93843238021688*x_5_2 + 191.65855055279948*x_5_3 + 139.5564401953561*x_5_4 + 93.47726996441435*x_5_6 + 225.39742678211746*x_5_7 + 14.866068747318506*x_5_8 + 232.7767170487633*x_5_9 + 109.55363982999378*x_6_0 + 72.42237223399962*x_6_1 + 75.0*x_6_2 + 184.39360075664231*x_6_3 + 111.61541112229978*x_6_4 + 93.47726996441435*x_6_5 + 186.03763060198332*x_6_7 + 107.54068997360952*x_6_8 + 161.38463371709216*x_6_9 + 86.64871608973787*x_7_0 + 223.57325421436258*x_7_1 + 251.7478897627545*x_7_2 + 72.00694410957877*x_7_3 + 85.88364221433555*x_7_4 + 225.39742678211746*x_7_5 + 186.03763060198332*x_7_6 + 229.92390045404153*x_7_8 + 86.37708029332781*x_7_9 + 184.13310403075272*x_8_0 + 40.0*x_8_1 + 77.88452991448301*x_8_2 + 191.80198122021577*x_8_3 + 144.55794685869054*x_8_4 + 14.866068747318506*x_8_5 + 107.54068997360952*x_8_6 + 229.92390045404153*x_8_7 + 242.1321952983535*x_8_9 + 58.008620049092706*x_9_0 + 221.63934668736056*x_9_1 + 236.07202290826416*x_9_2 + 147.75655653811103*x_9_3 + 113.65298060323803*x_9_4 + 232.7767170487633*x_9_5 + 161.38463371709216*x_9_6 + 86.37708029332781*x_9_7 + 242.1321952983535*x_9_8 + 0.0
# SUBJECT TO
# _C1: x_0_0 = 0
#
# _C2: x_1_1 = 0
#
# _C3: x_2_2 = 0
#
# _C4: x_3_3 = 0
#
# _C5: x_4_4 = 0
#
# _C6: x_5_5 = 0
#
# _C7: x_6_6 = 0
#
# _C8: x_7_7 = 0
#
# _C9: x_8_8 = 0
#
# _C10: x_9_9 = 0
#
# _C11: x_0_0 + x_1_0 + x_2_0 + x_3_0 + x_4_0 + x_5_0 + x_6_0 + x_7_0 + x_8_0
#  + x_9_0 = 1
#
# _C12: x_0_1 + x_1_1 + x_2_1 + x_3_1 + x_4_1 + x_5_1 + x_6_1 + x_7_1 + x_8_1
#  + x_9_1 = 1
#
# _C13: x_0_2 + x_1_2 + x_2_2 + x_3_2 + x_4_2 + x_5_2 + x_6_2 + x_7_2 + x_8_2
#  + x_9_2 = 1
#
# _C14: x_0_3 + x_1_3 + x_2_3 + x_3_3 + x_4_3 + x_5_3 + x_6_3 + x_7_3 + x_8_3
#  + x_9_3 = 1
#
# _C15: x_0_4 + x_1_4 + x_2_4 + x_3_4 + x_4_4 + x_5_4 + x_6_4 + x_7_4 + x_8_4
#  + x_9_4 = 1
#
# _C16: x_0_5 + x_1_5 + x_2_5 + x_3_5 + x_4_5 + x_5_5 + x_6_5 + x_7_5 + x_8_5
#  + x_9_5 = 1
#
# _C17: x_0_6 + x_1_6 + x_2_6 + x_3_6 + x_4_6 + x_5_6 + x_6_6 + x_7_6 + x_8_6
#  + x_9_6 = 1
#
# _C18: x_0_7 + x_1_7 + x_2_7 + x_3_7 + x_4_7 + x_5_7 + x_6_7 + x_7_7 + x_8_7
#  + x_9_7 = 1
#
# _C19: x_0_8 + x_1_8 + x_2_8 + x_3_8 + x_4_8 + x_5_8 + x_6_8 + x_7_8 + x_8_8
#  + x_9_8 = 1
#
# _C20: x_0_9 + x_1_9 + x_2_9 + x_3_9 + x_4_9 + x_5_9 + x_6_9 + x_7_9 + x_8_9
#  + x_9_9 = 1
#
# _C21: x_0_0 + x_0_1 + x_0_2 + x_0_3 + x_0_4 + x_0_5 + x_0_6 + x_0_7 + x_0_8
#  + x_0_9 = 1
#
# _C22: x_1_0 + x_1_1 + x_1_2 + x_1_3 + x_1_4 + x_1_5 + x_1_6 + x_1_7 + x_1_8
#  + x_1_9 = 1
#
# _C23: x_2_0 + x_2_1 + x_2_2 + x_2_3 + x_2_4 + x_2_5 + x_2_6 + x_2_7 + x_2_8
#  + x_2_9 = 1
#
# _C24: x_3_0 + x_3_1 + x_3_2 + x_3_3 + x_3_4 + x_3_5 + x_3_6 + x_3_7 + x_3_8
#  + x_3_9 = 1
#
# _C25: x_4_0 + x_4_1 + x_4_2 + x_4_3 + x_4_4 + x_4_5 + x_4_6 + x_4_7 + x_4_8
#  + x_4_9 = 1
#
# _C26: x_5_0 + x_5_1 + x_5_2 + x_5_3 + x_5_4 + x_5_5 + x_5_6 + x_5_7 + x_5_8
#  + x_5_9 = 1
#
# _C27: x_6_0 + x_6_1 + x_6_2 + x_6_3 + x_6_4 + x_6_5 + x_6_6 + x_6_7 + x_6_8
#  + x_6_9 = 1
#
# _C28: x_7_0 + x_7_1 + x_7_2 + x_7_3 + x_7_4 + x_7_5 + x_7_6 + x_7_7 + x_7_8
#  + x_7_9 = 1
#
# _C29: x_8_0 + x_8_1 + x_8_2 + x_8_3 + x_8_4 + x_8_5 + x_8_6 + x_8_7 + x_8_8
#  + x_8_9 = 1
#
# _C30: x_9_0 + x_9_1 + x_9_2 + x_9_3 + x_9_4 + x_9_5 + x_9_6 + x_9_7 + x_9_8
#  + x_9_9 = 1
#
# _C31: 0 u_1 + 10 x_1_1 <= 9
#
# _C32: u_1 - u_2 + 10 x_2_1 <= 9
#
# _C33: u_1 - u_3 + 10 x_3_1 <= 9
#
# _C34: u_1 - u_4 + 10 x_4_1 <= 9
#
# _C35: u_1 - u_5 + 10 x_5_1 <= 9
#
# _C36: u_1 - u_6 + 10 x_6_1 <= 9
#
# _C37: u_1 - u_7 + 10 x_7_1 <= 9
#
# _C38: u_1 - u_8 + 10 x_8_1 <= 9
#
# _C39: u_1 - u_9 + 10 x_9_1 <= 9
#
# _C40: - u_1 + u_2 + 10 x_1_2 <= 9
#
# _C41: 0 u_2 + 10 x_2_2 <= 9
#
# _C42: u_2 - u_3 + 10 x_3_2 <= 9
#
# _C43: u_2 - u_4 + 10 x_4_2 <= 9
#
# _C44: u_2 - u_5 + 10 x_5_2 <= 9
#
# _C45: u_2 - u_6 + 10 x_6_2 <= 9
#
# _C46: u_2 - u_7 + 10 x_7_2 <= 9
#
# _C47: u_2 - u_8 + 10 x_8_2 <= 9
#
# _C48: u_2 - u_9 + 10 x_9_2 <= 9
#
# _C49: - u_1 + u_3 + 10 x_1_3 <= 9
#
# _C50: - u_2 + u_3 + 10 x_2_3 <= 9
#
# _C51: 0 u_3 + 10 x_3_3 <= 9
#
# _C52: u_3 - u_4 + 10 x_4_3 <= 9
#
# _C53: u_3 - u_5 + 10 x_5_3 <= 9
#
# _C54: u_3 - u_6 + 10 x_6_3 <= 9
#
# _C55: u_3 - u_7 + 10 x_7_3 <= 9
#
# _C56: u_3 - u_8 + 10 x_8_3 <= 9
#
# _C57: u_3 - u_9 + 10 x_9_3 <= 9
#
# _C58: - u_1 + u_4 + 10 x_1_4 <= 9
#
# _C59: - u_2 + u_4 + 10 x_2_4 <= 9
#
# _C60: - u_3 + u_4 + 10 x_3_4 <= 9
#
# _C61: 0 u_4 + 10 x_4_4 <= 9
#
# _C62: u_4 - u_5 + 10 x_5_4 <= 9
#
# _C63: u_4 - u_6 + 10 x_6_4 <= 9
#
# _C64: u_4 - u_7 + 10 x_7_4 <= 9
#
# _C65: u_4 - u_8 + 10 x_8_4 <= 9
#
# _C66: u_4 - u_9 + 10 x_9_4 <= 9
#
# _C67: - u_1 + u_5 + 10 x_1_5 <= 9
#
# _C68: - u_2 + u_5 + 10 x_2_5 <= 9
#
# _C69: - u_3 + u_5 + 10 x_3_5 <= 9
#
# _C70: - u_4 + u_5 + 10 x_4_5 <= 9
#
# _C71: 0 u_5 + 10 x_5_5 <= 9
#
# _C72: u_5 - u_6 + 10 x_6_5 <= 9
#
# _C73: u_5 - u_7 + 10 x_7_5 <= 9
#
# _C74: u_5 - u_8 + 10 x_8_5 <= 9
#
# _C75: u_5 - u_9 + 10 x_9_5 <= 9
#
# _C76: - u_1 + u_6 + 10 x_1_6 <= 9
#
# _C77: - u_2 + u_6 + 10 x_2_6 <= 9
#
# _C78: - u_3 + u_6 + 10 x_3_6 <= 9
#
# _C79: - u_4 + u_6 + 10 x_4_6 <= 9
#
# _C80: - u_5 + u_6 + 10 x_5_6 <= 9
#
# _C81: 0 u_6 + 10 x_6_6 <= 9
#
# _C82: u_6 - u_7 + 10 x_7_6 <= 9
#
# _C83: u_6 - u_8 + 10 x_8_6 <= 9
#
# _C84: u_6 - u_9 + 10 x_9_6 <= 9
#
# _C85: - u_1 + u_7 + 10 x_1_7 <= 9
#
# _C86: - u_2 + u_7 + 10 x_2_7 <= 9
#
# _C87: - u_3 + u_7 + 10 x_3_7 <= 9
#
# _C88: - u_4 + u_7 + 10 x_4_7 <= 9
#
# _C89: - u_5 + u_7 + 10 x_5_7 <= 9
#
# _C90: - u_6 + u_7 + 10 x_6_7 <= 9
#
# _C91: 0 u_7 + 10 x_7_7 <= 9
#
# _C92: u_7 - u_8 + 10 x_8_7 <= 9
#
# _C93: u_7 - u_9 + 10 x_9_7 <= 9
#
# _C94: - u_1 + u_8 + 10 x_1_8 <= 9
#
# _C95: - u_2 + u_8 + 10 x_2_8 <= 9
#
# _C96: - u_3 + u_8 + 10 x_3_8 <= 9
#
# _C97: - u_4 + u_8 + 10 x_4_8 <= 9
#
# _C98: - u_5 + u_8 + 10 x_5_8 <= 9
#
# _C99: - u_6 + u_8 + 10 x_6_8 <= 9
#
# _C100: - u_7 + u_8 + 10 x_7_8 <= 9
#
# _C101: 0 u_8 + 10 x_8_8 <= 9
#
# _C102: u_8 - u_9 + 10 x_9_8 <= 9
#
# _C103: - u_1 + u_9 + 10 x_1_9 <= 9
#
# _C104: - u_2 + u_9 + 10 x_2_9 <= 9
#
# _C105: - u_3 + u_9 + 10 x_3_9 <= 9
#
# _C106: - u_4 + u_9 + 10 x_4_9 <= 9
#
# _C107: - u_5 + u_9 + 10 x_5_9 <= 9
#
# _C108: - u_6 + u_9 + 10 x_6_9 <= 9
#
# _C109: - u_7 + u_9 + 10 x_7_9 <= 9
#
# _C110: - u_8 + u_9 + 10 x_8_9 <= 9
#
# _C111: 0 u_9 + 10 x_9_9 <= 9
#
# VARIABLES
# 2 <= u_1 <= 10 Integer
# 2 <= u_2 <= 10 Integer
# 2 <= u_3 <= 10 Integer
# 2 <= u_4 <= 10 Integer
# 2 <= u_5 <= 10 Integer
# 2 <= u_6 <= 10 Integer
# 2 <= u_7 <= 10 Integer
# 2 <= u_8 <= 10 Integer
# 2 <= u_9 <= 10 Integer
# 0 <= x_0_0 <= 1 Integer
# 0 <= x_0_1 <= 1 Integer
# 0 <= x_0_2 <= 1 Integer
# 0 <= x_0_3 <= 1 Integer
# 0 <= x_0_4 <= 1 Integer
# 0 <= x_0_5 <= 1 Integer
# 0 <= x_0_6 <= 1 Integer
# 0 <= x_0_7 <= 1 Integer
# 0 <= x_0_8 <= 1 Integer
# 0 <= x_0_9 <= 1 Integer
# 0 <= x_1_0 <= 1 Integer
# 0 <= x_1_1 <= 1 Integer
# 0 <= x_1_2 <= 1 Integer
# 0 <= x_1_3 <= 1 Integer
# 0 <= x_1_4 <= 1 Integer
# 0 <= x_1_5 <= 1 Integer
# 0 <= x_1_6 <= 1 Integer
# 0 <= x_1_7 <= 1 Integer
# 0 <= x_1_8 <= 1 Integer
# 0 <= x_1_9 <= 1 Integer
# 0 <= x_2_0 <= 1 Integer
# 0 <= x_2_1 <= 1 Integer
# 0 <= x_2_2 <= 1 Integer
# 0 <= x_2_3 <= 1 Integer
# 0 <= x_2_4 <= 1 Integer
# 0 <= x_2_5 <= 1 Integer
# 0 <= x_2_6 <= 1 Integer
# 0 <= x_2_7 <= 1 Integer
# 0 <= x_2_8 <= 1 Integer
# 0 <= x_2_9 <= 1 Integer
# 0 <= x_3_0 <= 1 Integer
# 0 <= x_3_1 <= 1 Integer
# 0 <= x_3_2 <= 1 Integer
# 0 <= x_3_3 <= 1 Integer
# 0 <= x_3_4 <= 1 Integer
# 0 <= x_3_5 <= 1 Integer
# 0 <= x_3_6 <= 1 Integer
# 0 <= x_3_7 <= 1 Integer
# 0 <= x_3_8 <= 1 Integer
# 0 <= x_3_9 <= 1 Integer
# 0 <= x_4_0 <= 1 Integer
# 0 <= x_4_1 <= 1 Integer
# 0 <= x_4_2 <= 1 Integer
# 0 <= x_4_3 <= 1 Integer
# 0 <= x_4_4 <= 1 Integer
# 0 <= x_4_5 <= 1 Integer
# 0 <= x_4_6 <= 1 Integer
# 0 <= x_4_7 <= 1 Integer
# 0 <= x_4_8 <= 1 Integer
# 0 <= x_4_9 <= 1 Integer
# 0 <= x_5_0 <= 1 Integer
# 0 <= x_5_1 <= 1 Integer
# 0 <= x_5_2 <= 1 Integer
# 0 <= x_5_3 <= 1 Integer
# 0 <= x_5_4 <= 1 Integer
# 0 <= x_5_5 <= 1 Integer
# 0 <= x_5_6 <= 1 Integer
# 0 <= x_5_7 <= 1 Integer
# 0 <= x_5_8 <= 1 Integer
# 0 <= x_5_9 <= 1 Integer
# 0 <= x_6_0 <= 1 Integer
# 0 <= x_6_1 <= 1 Integer
# 0 <= x_6_2 <= 1 Integer
# 0 <= x_6_3 <= 1 Integer
# 0 <= x_6_4 <= 1 Integer
# 0 <= x_6_5 <= 1 Integer
# 0 <= x_6_6 <= 1 Integer
# 0 <= x_6_7 <= 1 Integer
# 0 <= x_6_8 <= 1 Integer
# 0 <= x_6_9 <= 1 Integer
# 0 <= x_7_0 <= 1 Integer
# 0 <= x_7_1 <= 1 Integer
# 0 <= x_7_2 <= 1 Integer
# 0 <= x_7_3 <= 1 Integer
# 0 <= x_7_4 <= 1 Integer
# 0 <= x_7_5 <= 1 Integer
# 0 <= x_7_6 <= 1 Integer
# 0 <= x_7_7 <= 1 Integer
# 0 <= x_7_8 <= 1 Integer
# 0 <= x_7_9 <= 1 Integer
# 0 <= x_8_0 <= 1 Integer
# 0 <= x_8_1 <= 1 Integer
# 0 <= x_8_2 <= 1 Integer
# 0 <= x_8_3 <= 1 Integer
# 0 <= x_8_4 <= 1 Integer
# 0 <= x_8_5 <= 1 Integer
# 0 <= x_8_6 <= 1 Integer
# 0 <= x_8_7 <= 1 Integer
# 0 <= x_8_8 <= 1 Integer
# 0 <= x_8_9 <= 1 Integer
# 0 <= x_9_0 <= 1 Integer
# 0 <= x_9_1 <= 1 Integer
# 0 <= x_9_2 <= 1 Integer
# 0 <= x_9_3 <= 1 Integer
# 0 <= x_9_4 <= 1 Integer
# 0 <= x_9_5 <= 1 Integer
# 0 <= x_9_6 <= 1 Integer
# 0 <= x_9_7 <= 1 Integer
# 0 <= x_9_8 <= 1 Integer
# 0 <= x_9_9 <= 1 Integer
#
# the minimal cycle length is  702.6934098934813
# [9, 7, 3, 4, 8, 5, 1, 2, 6, 0]

# %%
# Example 4
# Consider the following 12 points.
coordinates = [(0, 277), (234, 42), (269, 25), (12, 210), (298, 130), (10, 143), (270, 227), (87, 126), (34, 216), (93, 84), (40, 82), (27, 288)]
# Create a corresponding graph.
g = get_graph(coordinates)
# Compute an optimal Hamiltonian path using Integer Linear Programming:
cycle = ilp(g)
# Plot the resulting cycle
plot_cycle(coordinates, cycle)
# Out:
# TSP:
# MINIMIZE
# 331.6338342208165*x_0_1 + 199.06029237394384*x_0_10 + 29.154759474226502*x_0_11 + 368.5986977730659*x_0_2 + 68.06614430096654*x_0_3 + 332.2845166419886*x_0_4 + 134.3726162579266*x_0_5 + 274.5906043549196*x_0_6 + 174.26990560621763*x_0_7 + 69.83552104767315*x_0_8 + 214.23818520515897*x_0_9 + 199.06029237394384*x_10_0 + 198.08079159777205*x_10_1 + 206.4097865896867*x_10_11 + 235.9872877932199*x_10_2 + 131.0267148332736*x_10_3 + 262.42713274354844*x_10_4 + 67.97793759742936*x_10_5 + 271.89152248645047*x_10_6 + 64.38167441127949*x_10_7 + 134.13426109685773*x_10_8 + 53.03772242470448*x_10_9 + 29.154759474226502*x_11_0 + 321.50427679892533*x_11_1 + 206.4097865896867*x_11_10 + 357.39753776432207*x_11_2 + 79.42921376924235*x_11_3 + 313.6957124348371*x_11_4 + 145.9931505242626*x_11_5 + 250.53941805632104*x_11_6 + 172.75416058665562*x_11_7 + 72.3394774656273*x_11_8 + 214.41082062246764*x_11_9 + 331.6338342208165*x_1_0 + 198.08079159777205*x_1_10 + 321.50427679892533*x_1_11 + 38.91015291668744*x_1_2 + 278.40258619488435*x_1_3 + 108.81176406988355*x_1_4 + 245.7173172570464*x_1_5 + 188.47015678881365*x_1_6 + 169.30741271426953*x_1_7 + 265.0962089506374*x_1_8 + 147.12239802287073*x_1_9 + 368.5986977730659*x_2_0 + 38.91015291668744*x_2_1 + 235.9872877932199*x_2_10 + 357.39753776432207*x_2_11 + 316.6607016982057*x_2_3 + 108.93117092916977*x_2_4 + 284.6137733842127*x_2_5 + 202.00247523235947*x_2_6 + 208.1465829649865*x_2_7 + 302.8299853052864*x_2_8 + 185.62596801094398*x_2_9 + 68.06614430096654*x_3_0 + 278.40258619488435*x_3_1 + 131.0267148332736*x_3_10 + 79.42921376924235*x_3_11 + 316.6607016982057*x_3_2 + 296.97811367169805*x_3_4 + 67.02984409947557*x_3_5 + 258.55947091530027*x_3_6 + 112.60994627474076*x_3_7 + 22.80350850198276*x_3_8 + 149.78985279383915*x_3_9 + 332.2845166419886*x_4_0 + 108.81176406988355*x_4_1 + 262.42713274354844*x_4_10 + 313.6957124348371*x_4_11 + 108.93117092916977*x_4_2 + 296.97811367169805*x_4_3 + 288.29325347638644*x_4_5 + 100.96038827183659*x_4_6 + 211.03791128610044*x_4_7 + 277.65446151646836*x_4_8 + 210.09759636892565*x_4_9 + 134.3726162579266*x_5_0 + 245.7173172570464*x_5_1 + 67.97793759742936*x_5_10 + 145.9931505242626*x_5_11 + 284.6137733842127*x_5_2 + 67.02984409947557*x_5_3 + 288.29325347638644*x_5_4 + 273.23250172700904*x_5_6 + 78.85429601486528*x_5_7 + 76.84399781375251*x_5_8 + 101.83319694480774*x_5_9 + 274.5906043549196*x_6_0 + 188.47015678881365*x_6_1 + 271.89152248645047*x_6_10 + 250.53941805632104*x_6_11 + 202.00247523235947*x_6_2 + 258.55947091530027*x_6_3 + 100.96038827183659*x_6_4 + 273.23250172700904*x_6_5 + 209.02152999152983*x_6_7 + 236.25621684941964*x_6_8 + 227.547797176769*x_6_9 + 174.26990560621763*x_7_0 + 169.30741271426953*x_7_1 + 64.38167441127949*x_7_10 + 172.75416058665562*x_7_11 + 208.1465829649865*x_7_2 + 112.60994627474076*x_7_3 + 211.03791128610044*x_7_4 + 78.85429601486528*x_7_5 + 209.02152999152983*x_7_6 + 104.44615837837216*x_7_8 + 42.42640687119285*x_7_9 + 69.83552104767315*x_8_0 + 265.0962089506374*x_8_1 + 134.13426109685773*x_8_10 + 72.3394774656273*x_8_11 + 302.8299853052864*x_8_2 + 22.80350850198276*x_8_3 + 277.65446151646836*x_8_4 + 76.84399781375251*x_8_5 + 236.25621684941964*x_8_6 + 104.44615837837216*x_8_7 + 144.5856147754679*x_8_9 + 214.23818520515897*x_9_0 + 147.12239802287073*x_9_1 + 53.03772242470448*x_9_10 + 214.41082062246764*x_9_11 + 185.62596801094398*x_9_2 + 149.78985279383915*x_9_3 + 210.09759636892565*x_9_4 + 101.83319694480774*x_9_5 + 227.547797176769*x_9_6 + 42.42640687119285*x_9_7 + 144.5856147754679*x_9_8 + 0.0
# SUBJECT TO
# _C1: x_0_0 = 0
#
# _C2: x_1_1 = 0
#
# _C3: x_2_2 = 0
#
# _C4: x_3_3 = 0
#
# _C5: x_4_4 = 0
#
# _C6: x_5_5 = 0
#
# _C7: x_6_6 = 0
#
# _C8: x_7_7 = 0
#
# _C9: x_8_8 = 0
#
# _C10: x_9_9 = 0
#
# _C11: x_10_10 = 0
#
# _C12: x_11_11 = 0
#
# _C13: x_0_0 + x_10_0 + x_11_0 + x_1_0 + x_2_0 + x_3_0 + x_4_0 + x_5_0 + x_6_0
#  + x_7_0 + x_8_0 + x_9_0 = 1
#
# _C14: x_0_1 + x_10_1 + x_11_1 + x_1_1 + x_2_1 + x_3_1 + x_4_1 + x_5_1 + x_6_1
#  + x_7_1 + x_8_1 + x_9_1 = 1
#
# _C15: x_0_2 + x_10_2 + x_11_2 + x_1_2 + x_2_2 + x_3_2 + x_4_2 + x_5_2 + x_6_2
#  + x_7_2 + x_8_2 + x_9_2 = 1
#
# _C16: x_0_3 + x_10_3 + x_11_3 + x_1_3 + x_2_3 + x_3_3 + x_4_3 + x_5_3 + x_6_3
#  + x_7_3 + x_8_3 + x_9_3 = 1
#
# _C17: x_0_4 + x_10_4 + x_11_4 + x_1_4 + x_2_4 + x_3_4 + x_4_4 + x_5_4 + x_6_4
#  + x_7_4 + x_8_4 + x_9_4 = 1
#
# _C18: x_0_5 + x_10_5 + x_11_5 + x_1_5 + x_2_5 + x_3_5 + x_4_5 + x_5_5 + x_6_5
#  + x_7_5 + x_8_5 + x_9_5 = 1
#
# _C19: x_0_6 + x_10_6 + x_11_6 + x_1_6 + x_2_6 + x_3_6 + x_4_6 + x_5_6 + x_6_6
#  + x_7_6 + x_8_6 + x_9_6 = 1
#
# _C20: x_0_7 + x_10_7 + x_11_7 + x_1_7 + x_2_7 + x_3_7 + x_4_7 + x_5_7 + x_6_7
#  + x_7_7 + x_8_7 + x_9_7 = 1
#
# _C21: x_0_8 + x_10_8 + x_11_8 + x_1_8 + x_2_8 + x_3_8 + x_4_8 + x_5_8 + x_6_8
#  + x_7_8 + x_8_8 + x_9_8 = 1
#
# _C22: x_0_9 + x_10_9 + x_11_9 + x_1_9 + x_2_9 + x_3_9 + x_4_9 + x_5_9 + x_6_9
#  + x_7_9 + x_8_9 + x_9_9 = 1
#
# _C23: x_0_10 + x_10_10 + x_11_10 + x_1_10 + x_2_10 + x_3_10 + x_4_10 + x_5_10
#  + x_6_10 + x_7_10 + x_8_10 + x_9_10 = 1
#
# _C24: x_0_11 + x_10_11 + x_11_11 + x_1_11 + x_2_11 + x_3_11 + x_4_11 + x_5_11
#  + x_6_11 + x_7_11 + x_8_11 + x_9_11 = 1
#
# _C25: x_0_0 + x_0_1 + x_0_10 + x_0_11 + x_0_2 + x_0_3 + x_0_4 + x_0_5 + x_0_6
#  + x_0_7 + x_0_8 + x_0_9 = 1
#
# _C26: x_1_0 + x_1_1 + x_1_10 + x_1_11 + x_1_2 + x_1_3 + x_1_4 + x_1_5 + x_1_6
#  + x_1_7 + x_1_8 + x_1_9 = 1
#
# _C27: x_2_0 + x_2_1 + x_2_10 + x_2_11 + x_2_2 + x_2_3 + x_2_4 + x_2_5 + x_2_6
#  + x_2_7 + x_2_8 + x_2_9 = 1
#
# _C28: x_3_0 + x_3_1 + x_3_10 + x_3_11 + x_3_2 + x_3_3 + x_3_4 + x_3_5 + x_3_6
#  + x_3_7 + x_3_8 + x_3_9 = 1
#
# _C29: x_4_0 + x_4_1 + x_4_10 + x_4_11 + x_4_2 + x_4_3 + x_4_4 + x_4_5 + x_4_6
#  + x_4_7 + x_4_8 + x_4_9 = 1
#
# _C30: x_5_0 + x_5_1 + x_5_10 + x_5_11 + x_5_2 + x_5_3 + x_5_4 + x_5_5 + x_5_6
#  + x_5_7 + x_5_8 + x_5_9 = 1
#
# _C31: x_6_0 + x_6_1 + x_6_10 + x_6_11 + x_6_2 + x_6_3 + x_6_4 + x_6_5 + x_6_6
#  + x_6_7 + x_6_8 + x_6_9 = 1
#
# _C32: x_7_0 + x_7_1 + x_7_10 + x_7_11 + x_7_2 + x_7_3 + x_7_4 + x_7_5 + x_7_6
#  + x_7_7 + x_7_8 + x_7_9 = 1
#
# _C33: x_8_0 + x_8_1 + x_8_10 + x_8_11 + x_8_2 + x_8_3 + x_8_4 + x_8_5 + x_8_6
#  + x_8_7 + x_8_8 + x_8_9 = 1
#
# _C34: x_9_0 + x_9_1 + x_9_10 + x_9_11 + x_9_2 + x_9_3 + x_9_4 + x_9_5 + x_9_6
#  + x_9_7 + x_9_8 + x_9_9 = 1
#
# _C35: x_10_0 + x_10_1 + x_10_10 + x_10_11 + x_10_2 + x_10_3 + x_10_4 + x_10_5
#  + x_10_6 + x_10_7 + x_10_8 + x_10_9 = 1
#
# _C36: x_11_0 + x_11_1 + x_11_10 + x_11_11 + x_11_2 + x_11_3 + x_11_4 + x_11_5
#  + x_11_6 + x_11_7 + x_11_8 + x_11_9 = 1
#
# _C37: 0 u_1 + 12 x_1_1 <= 11
#
# _C38: u_1 - u_2 + 12 x_2_1 <= 11
#
# _C39: u_1 - u_3 + 12 x_3_1 <= 11
#
# _C40: u_1 - u_4 + 12 x_4_1 <= 11
#
# _C41: u_1 - u_5 + 12 x_5_1 <= 11
#
# _C42: u_1 - u_6 + 12 x_6_1 <= 11
#
# _C43: u_1 - u_7 + 12 x_7_1 <= 11
#
# _C44: u_1 - u_8 + 12 x_8_1 <= 11
#
# _C45: u_1 - u_9 + 12 x_9_1 <= 11
#
# _C46: u_1 - u_10 + 12 x_10_1 <= 11
#
# _C47: u_1 - u_11 + 12 x_11_1 <= 11
#
# _C48: - u_1 + u_2 + 12 x_1_2 <= 11
#
# _C49: 0 u_2 + 12 x_2_2 <= 11
#
# _C50: u_2 - u_3 + 12 x_3_2 <= 11
#
# _C51: u_2 - u_4 + 12 x_4_2 <= 11
#
# _C52: u_2 - u_5 + 12 x_5_2 <= 11
#
# _C53: u_2 - u_6 + 12 x_6_2 <= 11
#
# _C54: u_2 - u_7 + 12 x_7_2 <= 11
#
# _C55: u_2 - u_8 + 12 x_8_2 <= 11
#
# _C56: u_2 - u_9 + 12 x_9_2 <= 11
#
# _C57: - u_10 + u_2 + 12 x_10_2 <= 11
#
# _C58: - u_11 + u_2 + 12 x_11_2 <= 11
#
# _C59: - u_1 + u_3 + 12 x_1_3 <= 11
#
# _C60: - u_2 + u_3 + 12 x_2_3 <= 11
#
# _C61: 0 u_3 + 12 x_3_3 <= 11
#
# _C62: u_3 - u_4 + 12 x_4_3 <= 11
#
# _C63: u_3 - u_5 + 12 x_5_3 <= 11
#
# _C64: u_3 - u_6 + 12 x_6_3 <= 11
#
# _C65: u_3 - u_7 + 12 x_7_3 <= 11
#
# _C66: u_3 - u_8 + 12 x_8_3 <= 11
#
# _C67: u_3 - u_9 + 12 x_9_3 <= 11
#
# _C68: - u_10 + u_3 + 12 x_10_3 <= 11
#
# _C69: - u_11 + u_3 + 12 x_11_3 <= 11
#
# _C70: - u_1 + u_4 + 12 x_1_4 <= 11
#
# _C71: - u_2 + u_4 + 12 x_2_4 <= 11
#
# _C72: - u_3 + u_4 + 12 x_3_4 <= 11
#
# _C73: 0 u_4 + 12 x_4_4 <= 11
#
# _C74: u_4 - u_5 + 12 x_5_4 <= 11
#
# _C75: u_4 - u_6 + 12 x_6_4 <= 11
#
# _C76: u_4 - u_7 + 12 x_7_4 <= 11
#
# _C77: u_4 - u_8 + 12 x_8_4 <= 11
#
# _C78: u_4 - u_9 + 12 x_9_4 <= 11
#
# _C79: - u_10 + u_4 + 12 x_10_4 <= 11
#
# _C80: - u_11 + u_4 + 12 x_11_4 <= 11
#
# _C81: - u_1 + u_5 + 12 x_1_5 <= 11
#
# _C82: - u_2 + u_5 + 12 x_2_5 <= 11
#
# _C83: - u_3 + u_5 + 12 x_3_5 <= 11
#
# _C84: - u_4 + u_5 + 12 x_4_5 <= 11
#
# _C85: 0 u_5 + 12 x_5_5 <= 11
#
# _C86: u_5 - u_6 + 12 x_6_5 <= 11
#
# _C87: u_5 - u_7 + 12 x_7_5 <= 11
#
# _C88: u_5 - u_8 + 12 x_8_5 <= 11
#
# _C89: u_5 - u_9 + 12 x_9_5 <= 11
#
# _C90: - u_10 + u_5 + 12 x_10_5 <= 11
#
# _C91: - u_11 + u_5 + 12 x_11_5 <= 11
#
# _C92: - u_1 + u_6 + 12 x_1_6 <= 11
#
# _C93: - u_2 + u_6 + 12 x_2_6 <= 11
#
# _C94: - u_3 + u_6 + 12 x_3_6 <= 11
#
# _C95: - u_4 + u_6 + 12 x_4_6 <= 11
#
# _C96: - u_5 + u_6 + 12 x_5_6 <= 11
#
# _C97: 0 u_6 + 12 x_6_6 <= 11
#
# _C98: u_6 - u_7 + 12 x_7_6 <= 11
#
# _C99: u_6 - u_8 + 12 x_8_6 <= 11
#
# _C100: u_6 - u_9 + 12 x_9_6 <= 11
#
# _C101: - u_10 + u_6 + 12 x_10_6 <= 11
#
# _C102: - u_11 + u_6 + 12 x_11_6 <= 11
#
# _C103: - u_1 + u_7 + 12 x_1_7 <= 11
#
# _C104: - u_2 + u_7 + 12 x_2_7 <= 11
#
# _C105: - u_3 + u_7 + 12 x_3_7 <= 11
#
# _C106: - u_4 + u_7 + 12 x_4_7 <= 11
#
# _C107: - u_5 + u_7 + 12 x_5_7 <= 11
#
# _C108: - u_6 + u_7 + 12 x_6_7 <= 11
#
# _C109: 0 u_7 + 12 x_7_7 <= 11
#
# _C110: u_7 - u_8 + 12 x_8_7 <= 11
#
# _C111: u_7 - u_9 + 12 x_9_7 <= 11
#
# _C112: - u_10 + u_7 + 12 x_10_7 <= 11
#
# _C113: - u_11 + u_7 + 12 x_11_7 <= 11
#
# _C114: - u_1 + u_8 + 12 x_1_8 <= 11
#
# _C115: - u_2 + u_8 + 12 x_2_8 <= 11
#
# _C116: - u_3 + u_8 + 12 x_3_8 <= 11
#
# _C117: - u_4 + u_8 + 12 x_4_8 <= 11
#
# _C118: - u_5 + u_8 + 12 x_5_8 <= 11
#
# _C119: - u_6 + u_8 + 12 x_6_8 <= 11
#
# _C120: - u_7 + u_8 + 12 x_7_8 <= 11
#
# _C121: 0 u_8 + 12 x_8_8 <= 11
#
# _C122: u_8 - u_9 + 12 x_9_8 <= 11
#
# _C123: - u_10 + u_8 + 12 x_10_8 <= 11
#
# _C124: - u_11 + u_8 + 12 x_11_8 <= 11
#
# _C125: - u_1 + u_9 + 12 x_1_9 <= 11
#
# _C126: - u_2 + u_9 + 12 x_2_9 <= 11
#
# _C127: - u_3 + u_9 + 12 x_3_9 <= 11
#
# _C128: - u_4 + u_9 + 12 x_4_9 <= 11
#
# _C129: - u_5 + u_9 + 12 x_5_9 <= 11
#
# _C130: - u_6 + u_9 + 12 x_6_9 <= 11
#
# _C131: - u_7 + u_9 + 12 x_7_9 <= 11
#
# _C132: - u_8 + u_9 + 12 x_8_9 <= 11
#
# _C133: 0 u_9 + 12 x_9_9 <= 11
#
# _C134: - u_10 + u_9 + 12 x_10_9 <= 11
#
# _C135: - u_11 + u_9 + 12 x_11_9 <= 11
#
# _C136: - u_1 + u_10 + 12 x_1_10 <= 11
#
# _C137: u_10 - u_2 + 12 x_2_10 <= 11
#
# _C138: u_10 - u_3 + 12 x_3_10 <= 11
#
# _C139: u_10 - u_4 + 12 x_4_10 <= 11
#
# _C140: u_10 - u_5 + 12 x_5_10 <= 11
#
# _C141: u_10 - u_6 + 12 x_6_10 <= 11
#
# _C142: u_10 - u_7 + 12 x_7_10 <= 11
#
# _C143: u_10 - u_8 + 12 x_8_10 <= 11
#
# _C144: u_10 - u_9 + 12 x_9_10 <= 11
#
# _C145: 0 u_10 + 12 x_10_10 <= 11
#
# _C146: u_10 - u_11 + 12 x_11_10 <= 11
#
# _C147: - u_1 + u_11 + 12 x_1_11 <= 11
#
# _C148: u_11 - u_2 + 12 x_2_11 <= 11
#
# _C149: u_11 - u_3 + 12 x_3_11 <= 11
#
# _C150: u_11 - u_4 + 12 x_4_11 <= 11
#
# _C151: u_11 - u_5 + 12 x_5_11 <= 11
#
# _C152: u_11 - u_6 + 12 x_6_11 <= 11
#
# _C153: u_11 - u_7 + 12 x_7_11 <= 11
#
# _C154: u_11 - u_8 + 12 x_8_11 <= 11
#
# _C155: u_11 - u_9 + 12 x_9_11 <= 11
#
# _C156: - u_10 + u_11 + 12 x_10_11 <= 11
#
# _C157: 0 u_11 + 12 x_11_11 <= 11
#
# VARIABLES
# 2 <= u_1 <= 12 Integer
# 2 <= u_10 <= 12 Integer
# 2 <= u_11 <= 12 Integer
# 2 <= u_2 <= 12 Integer
# 2 <= u_3 <= 12 Integer
# 2 <= u_4 <= 12 Integer
# 2 <= u_5 <= 12 Integer
# 2 <= u_6 <= 12 Integer
# 2 <= u_7 <= 12 Integer
# 2 <= u_8 <= 12 Integer
# 2 <= u_9 <= 12 Integer
# 0 <= x_0_0 <= 1 Integer
# 0 <= x_0_1 <= 1 Integer
# 0 <= x_0_10 <= 1 Integer
# 0 <= x_0_11 <= 1 Integer
# 0 <= x_0_2 <= 1 Integer
# 0 <= x_0_3 <= 1 Integer
# 0 <= x_0_4 <= 1 Integer
# 0 <= x_0_5 <= 1 Integer
# 0 <= x_0_6 <= 1 Integer
# 0 <= x_0_7 <= 1 Integer
# 0 <= x_0_8 <= 1 Integer
# 0 <= x_0_9 <= 1 Integer
# 0 <= x_10_0 <= 1 Integer
# 0 <= x_10_1 <= 1 Integer
# 0 <= x_10_10 <= 1 Integer
# 0 <= x_10_11 <= 1 Integer
# 0 <= x_10_2 <= 1 Integer
# 0 <= x_10_3 <= 1 Integer
# 0 <= x_10_4 <= 1 Integer
# 0 <= x_10_5 <= 1 Integer
# 0 <= x_10_6 <= 1 Integer
# 0 <= x_10_7 <= 1 Integer
# 0 <= x_10_8 <= 1 Integer
# 0 <= x_10_9 <= 1 Integer
# 0 <= x_11_0 <= 1 Integer
# 0 <= x_11_1 <= 1 Integer
# 0 <= x_11_10 <= 1 Integer
# 0 <= x_11_11 <= 1 Integer
# 0 <= x_11_2 <= 1 Integer
# 0 <= x_11_3 <= 1 Integer
# 0 <= x_11_4 <= 1 Integer
# 0 <= x_11_5 <= 1 Integer
# 0 <= x_11_6 <= 1 Integer
# 0 <= x_11_7 <= 1 Integer
# 0 <= x_11_8 <= 1 Integer
# 0 <= x_11_9 <= 1 Integer
# 0 <= x_1_0 <= 1 Integer
# 0 <= x_1_1 <= 1 Integer
# 0 <= x_1_10 <= 1 Integer
# 0 <= x_1_11 <= 1 Integer
# 0 <= x_1_2 <= 1 Integer
# 0 <= x_1_3 <= 1 Integer
# 0 <= x_1_4 <= 1 Integer
# 0 <= x_1_5 <= 1 Integer
# 0 <= x_1_6 <= 1 Integer
# 0 <= x_1_7 <= 1 Integer
# 0 <= x_1_8 <= 1 Integer
# 0 <= x_1_9 <= 1 Integer
# 0 <= x_2_0 <= 1 Integer
# 0 <= x_2_1 <= 1 Integer
# 0 <= x_2_10 <= 1 Integer
# 0 <= x_2_11 <= 1 Integer
# 0 <= x_2_2 <= 1 Integer
# 0 <= x_2_3 <= 1 Integer
# 0 <= x_2_4 <= 1 Integer
# 0 <= x_2_5 <= 1 Integer
# 0 <= x_2_6 <= 1 Integer
# 0 <= x_2_7 <= 1 Integer
# 0 <= x_2_8 <= 1 Integer
# 0 <= x_2_9 <= 1 Integer
# 0 <= x_3_0 <= 1 Integer
# 0 <= x_3_1 <= 1 Integer
# 0 <= x_3_10 <= 1 Integer
# 0 <= x_3_11 <= 1 Integer
# 0 <= x_3_2 <= 1 Integer
# 0 <= x_3_3 <= 1 Integer
# 0 <= x_3_4 <= 1 Integer
# 0 <= x_3_5 <= 1 Integer
# 0 <= x_3_6 <= 1 Integer
# 0 <= x_3_7 <= 1 Integer
# 0 <= x_3_8 <= 1 Integer
# 0 <= x_3_9 <= 1 Integer
# 0 <= x_4_0 <= 1 Integer
# 0 <= x_4_1 <= 1 Integer
# 0 <= x_4_10 <= 1 Integer
# 0 <= x_4_11 <= 1 Integer
# 0 <= x_4_2 <= 1 Integer
# 0 <= x_4_3 <= 1 Integer
# 0 <= x_4_4 <= 1 Integer
# 0 <= x_4_5 <= 1 Integer
# 0 <= x_4_6 <= 1 Integer
# 0 <= x_4_7 <= 1 Integer
# 0 <= x_4_8 <= 1 Integer
# 0 <= x_4_9 <= 1 Integer
# 0 <= x_5_0 <= 1 Integer
# 0 <= x_5_1 <= 1 Integer
# 0 <= x_5_10 <= 1 Integer
# 0 <= x_5_11 <= 1 Integer
# 0 <= x_5_2 <= 1 Integer
# 0 <= x_5_3 <= 1 Integer
# 0 <= x_5_4 <= 1 Integer
# 0 <= x_5_5 <= 1 Integer
# 0 <= x_5_6 <= 1 Integer
# 0 <= x_5_7 <= 1 Integer
# 0 <= x_5_8 <= 1 Integer
# 0 <= x_5_9 <= 1 Integer
# 0 <= x_6_0 <= 1 Integer
# 0 <= x_6_1 <= 1 Integer
# 0 <= x_6_10 <= 1 Integer
# 0 <= x_6_11 <= 1 Integer
# 0 <= x_6_2 <= 1 Integer
# 0 <= x_6_3 <= 1 Integer
# 0 <= x_6_4 <= 1 Integer
# 0 <= x_6_5 <= 1 Integer
# 0 <= x_6_6 <= 1 Integer
# 0 <= x_6_7 <= 1 Integer
# 0 <= x_6_8 <= 1 Integer
# 0 <= x_6_9 <= 1 Integer
# 0 <= x_7_0 <= 1 Integer
# 0 <= x_7_1 <= 1 Integer
# 0 <= x_7_10 <= 1 Integer
# 0 <= x_7_11 <= 1 Integer
# 0 <= x_7_2 <= 1 Integer
# 0 <= x_7_3 <= 1 Integer
# 0 <= x_7_4 <= 1 Integer
# 0 <= x_7_5 <= 1 Integer
# 0 <= x_7_6 <= 1 Integer
# 0 <= x_7_7 <= 1 Integer
# 0 <= x_7_8 <= 1 Integer
# 0 <= x_7_9 <= 1 Integer
# 0 <= x_8_0 <= 1 Integer
# 0 <= x_8_1 <= 1 Integer
# 0 <= x_8_10 <= 1 Integer
# 0 <= x_8_11 <= 1 Integer
# 0 <= x_8_2 <= 1 Integer
# 0 <= x_8_3 <= 1 Integer
# 0 <= x_8_4 <= 1 Integer
# 0 <= x_8_5 <= 1 Integer
# 0 <= x_8_6 <= 1 Integer
# 0 <= x_8_7 <= 1 Integer
# 0 <= x_8_8 <= 1 Integer
# 0 <= x_8_9 <= 1 Integer
# 0 <= x_9_0 <= 1 Integer
# 0 <= x_9_1 <= 1 Integer
# 0 <= x_9_10 <= 1 Integer
# 0 <= x_9_11 <= 1 Integer
# 0 <= x_9_2 <= 1 Integer
# 0 <= x_9_3 <= 1 Integer
# 0 <= x_9_4 <= 1 Integer
# 0 <= x_9_5 <= 1 Integer
# 0 <= x_9_6 <= 1 Integer
# 0 <= x_9_7 <= 1 Integer
# 0 <= x_9_8 <= 1 Integer
# 0 <= x_9_9 <= 1 Integer
#
# the minimal cycle length is  1010.0731802001451

# %%
# Example 5
# Consider the following 14 points.
coordinates = [(111, 191), (197, 164), (219, 204), (206, 91), (255, 274), (265, 155), (76, 284), (292, 129), (191, 36), (37, 156), (21, 20), (198, 248), (221, 153), (92, 133)]
# Create a corresponding graph.
g = get_graph(coordinates)
# Compute an optimal Hamiltonian path using Integer Linear Programming:
cycle = ilp(g)
# Plot the resulting cycle
plot_cycle(coordinates, cycle)
# Out:
# 4224133723*x_0_3 + 166.20770138594662*x_0_4 + 158.15182578775372*x_0_5 + 99.36800289831733*x_0_6 + 191.3243319601561*x_0_7 + 174.42763542512407*x_0_8 + 81.85963596303125*x_0_9 + 193.238194982255*x_10_0 + 227.40272645683032*x_10_1 + 288.63991407980984*x_10_11 + 240.18534509832193*x_10_12 + 133.4541119636259*x_10_13 + 270.29613389761977*x_10_2 + 198.15650380444242*x_10_3 + 345.35778549208936*x_10_4 + 278.85659396901485*x_10_5 + 269.6683147868878*x_10_6 + 292.09929818470977*x_10_7 + 170.75128110793196*x_10_8 + 136.93794214898952*x_10_9 + 104.0096149401583*x_11_0 + 84.00595217006948*x_11_1 + 288.63991407980984*x_11_10 + 97.74456506629922*x_11_12 + 156.40012787718558*x_11_13 + 48.75448697299562*x_11_2 + 157.20368952413298*x_11_3 + 62.64982043070834*x_11_4 + 114.62111498323509*x_11_5 + 127.20062892926276*x_11_6 + 151.64761785138597*x_11_7 + 212.11553455605272*x_11_8 + 185.43192821086663*x_11_9 + 116.37869220780924*x_12_0 + 26.40075756488817*x_12_1 + 240.18534509832193*x_12_10 + 97.74456506629922*x_12_11 + 130.54118124178285*x_12_13 + 51.03920062069938*x_12_2 + 63.788713735268246*x_12_3 + 125.686116973992*x_12_4 + 44.04543109109048*x_12_5 + 195.41238445912276*x_12_6 + 74.94664769020693*x_12_7 + 120.78493283518438*x_12_8 + 184.0244548966251*x_12_9 + 61.032778078668514*x_13_0 + 109.48059188732951*x_13_1 + 133.4541119636259*x_13_10 + 156.40012787718558*x_13_11 + 130.54118124178285*x_13_12 + 145.49914089093448*x_13_2 + 121.49074038789952*x_13_3 + 215.52262062252305*x_13_4 + 174.39323381370048*x_13_5 + 151.8453160291749*x_13_6 + 200.0399960007998*x_13_7 + 138.6001443000692*x_13_8 + 59.61543424315552*x_13_9 + 90.13878188659973*x_1_0 + 227.40272645683032*x_1_10 + 84.00595217006948*x_1_11 + 26.40075756488817*x_1_12 + 109.48059188732951*x_1_13 + 45.65084884205331*x_1_2 + 73.55270219373317*x_1_3 + 124.35433245367851*x_1_4 + 68.59300255857006*x_1_5 + 170.41420128616042*x_1_6 + 101.24228365658294*x_1_7 + 128.14054783713078*x_1_8 + 160.1998751560063*x_1_9 + 108.77959367454909*x_2_0 + 45.65084884205331*x_2_1 + 270.29613389761977*x_2_10 + 48.75448697299562*x_2_11 + 51.03920062069938*x_2_12 + 145.49914089093448*x_2_13 + 113.7453295744489*x_2_3 + 78.71467461661771*x_2_4 + 67.20863039818622*x_2_5 + 163.8566446623389*x_2_6 + 104.66135867644753*x_2_7 + 170.31735084835015*x_2_8 + 188.22327167489146*x_2_9 + 137.93114224133723*x_3_0 + 73.55270219373317*x_3_1 + 198.15650380444242*x_3_10 + 157.20368952413298*x_3_11 + 63.788713735268246*x_3_12 + 121.49074038789952*x_3_13 + 113.7453295744489*x_3_2 + 189.44656238633627*x_3_4 + 87.04596486914255*x_3_5 + 232.69937687926884*x_3_6 + 94.02127418834527*x_3_7 + 57.0087712549569*x_3_8 + 181.06904760339356*x_3_9 + 166.20770138594662*x_4_0 + 124.35433245367851*x_4_1 + 345.35778549208936*x_4_10 + 62.64982043070834*x_4_11 + 125.686116973992*x_4_12 + 215.52262062252305*x_4_13 + 78.71467461661771*x_4_2 + 189.44656238633627*x_4_3 + 119.41942890501528*x_4_5 + 179.27911200137063*x_4_6 + 149.64624953536256*x_4_7 + 246.45486402179202*x_4_8 + 247.88707106261108*x_4_9 + 158.15182578775372*x_5_0 + 68.59300255857006*x_5_1 + 278.85659396901485*x_5_10 + 114.62111498323509*x_5_11 + 44.04543109109048*x_5_12 + 174.39323381370048*x_5_13 + 67.20863039818622*x_5_2 + 87.04596486914255*x_5_3 + 119.41942890501528*x_5_4 + 228.82744590629858*x_5_6 + 37.48332962798263*x_5_7 + 140.13208055259867*x_5_8 + 228.0021929719098*x_5_9 + 99.36800289831733*x_6_0 + 170.41420128616042*x_6_1 + 269.6683147868878*x_6_10 + 127.20062892926276*x_6_11 + 195.41238445912276*x_6_12 + 151.8453160291749*x_6_13 + 163.8566446623389*x_6_2 + 232.69937687926884*x_6_3 + 179.27911200137063*x_6_4 + 228.82744590629858*x_6_5 + 265.8589851782332*x_6_7 + 273.36605495196363*x_6_8 + 133.80956617521784*x_6_9 + 191.3243319601561*x_7_0 + 101.24228365658294*x_7_1 + 292.09929818470977*x_7_10 + 151.64761785138597*x_7_11 + 74.94664769020693*x_7_12 + 200.0399960007998*x_7_13 + 104.66135867644753*x_7_2 + 94.02127418834527*x_7_3 + 149.64624953536256*x_7_4 + 37.48332962798263*x_7_5 + 265.85898517 ...
# SUBJECT TO
# _C1: x_0_0 = 0
#
# _C2: x_1_1 = 0
#
# _C3: x_2_2 = 0
#
# _C4: x_3_3 = 0
#
# _C5: x_4_4 = 0
#
# _C6: x_5_5 = 0
#
# _C7: x_6_6 = 0
#
# _C8: x_7_7 = 0
#
# _C9: x_8_8 = 0
#
# _C10: x_9_9 = 0
#
# _C11: x_10_10 = 0
#
# _C12: x_11_11 = 0
#
# _C13: x_12_12 = 0
#
# _C14: x_13_13 = 0
#
# _C15: x_0_0 + x_10_0 + x_11_0 + x_12_0 + x_13_0 + x_1_0 + x_2_0 + x_3_0
#  + x_4_0 + x_5_0 + x_6_0 + x_7_0 + x_8_0 + x_9_0 = 1
#
# _C16: x_0_1 + x_10_1 + x_11_1 + x_12_1 + x_13_1 + x_1_1 + x_2_1 + x_3_1
#  + x_4_1 + x_5_1 + x_6_1 + x_7_1 + x_8_1 + x_9_1 = 1
#
# _C17: x_0_2 + x_10_2 + x_11_2 + x_12_2 + x_13_2 + x_1_2 + x_2_2 + x_3_2
#  + x_4_2 + x_5_2 + x_6_2 + x_7_2 + x_8_2 + x_9_2 = 1
#
# _C18: x_0_3 + x_10_3 + x_11_3 + x_12_3 + x_13_3 + x_1_3 + x_2_3 + x_3_3
#  + x_4_3 + x_5_3 + x_6_3 + x_7_3 + x_8_3 + x_9_3 = 1
#
# _C19: x_0_4 + x_10_4 + x_11_4 + x_12_4 + x_13_4 + x_1_4 + x_2_4 + x_3_4
#  + x_4_4 + x_5_4 + x_6_4 + x_7_4 + x_8_4 + x_9_4 = 1
#
# _C20: x_0_5 + x_10_5 + x_11_5 + x_12_5 + x_13_5 + x_1_5 + x_2_5 + x_3_5
#  + x_4_5 + x_5_5 + x_6_5 + x_7_5 + x_8_5 + x_9_5 = 1
#
# _C21: x_0_6 + x_10_6 + x_11_6 + x_12_6 + x_13_6 + x_1_6 + x_2_6 + x_3_6
#  + x_4_6 + x_5_6 + x_6_6 + x_7_6 + x_8_6 + x_9_6 = 1
#
# _C22: x_0_7 + x_10_7 + x_11_7 + x_12_7 + x_13_7 + x_1_7 + x_2_7 + x_3_7
#  + x_4_7 + x_5_7 + x_6_7 + x_7_7 + x_8_7 + x_9_7 = 1
#
# _C23: x_0_8 + x_10_8 + x_11_8 + x_12_8 + x_13_8 + x_1_8 + x_2_8 + x_3_8
#  + x_4_8 + x_5_8 + x_6_8 + x_7_8 + x_8_8 + x_9_8 = 1
#
# _C24: x_0_9 + x_10_9 + x_11_9 + x_12_9 + x_13_9 + x_1_9 + x_2_9 + x_3_9
#  + x_4_9 + x_5_9 + x_6_9 + x_7_9 + x_8_9 + x_9_9 = 1
#
# _C25: x_0_10 + x_10_10 + x_11_10 + x_12_10 + x_13_10 + x_1_10 + x_2_10
#  + x_3_10 + x_4_10 + x_5_10 + x_6_10 + x_7_10 + x_8_10 + x_9_10 = 1
#
# _C26: x_0_11 + x_10_11 + x_11_11 + x_12_11 + x_13_11 + x_1_11 + x_2_11
#  + x_3_11 + x_4_11 + x_5_11 + x_6_11 + x_7_11 + x_8_11 + x_9_11 = 1
#
# _C27: x_0_12 + x_10_12 + x_11_12 + x_12_12 + x_13_12 + x_1_12 + x_2_12
#  + x_3_12 + x_4_12 + x_5_12 + x_6_12 + x_7_12 + x_8_12 + x_9_12 = 1
#
# _C28: x_0_13 + x_10_13 + x_11_13 + x_12_13 + x_13_13 + x_1_13 + x_2_13
#  + x_3_13 + x_4_13 + x_5_13 + x_6_13 + x_7_13 + x_8_13 + x_9_13 = 1
#
# _C29: x_0_0 + x_0_1 + x_0_10 + x_0_11 + x_0_12 + x_0_13 + x_0_2 + x_0_3
#  + x_0_4 + x_0_5 + x_0_6 + x_0_7 + x_0_8 + x_0_9 = 1
#
# _C30: x_1_0 + x_1_1 + x_1_10 + x_1_11 + x_1_12 + x_1_13 + x_1_2 + x_1_3
#  + x_1_4 + x_1_5 + x_1_6 + x_1_7 + x_1_8 + x_1_9 = 1
#
# _C31: x_2_0 + x_2_1 + x_2_10 + x_2_11 + x_2_12 + x_2_13 + x_2_2 + x_2_3
#  + x_2_4 + x_2_5 + x_2_6 + x_2_7 + x_2_8 + x_2_9 = 1
#
# _C32: x_3_0 + x_3_1 + x_3_10 + x_3_11 + x_3_12 + x_3_13 + x_3_2 + x_3_3
#  + x_3_4 + x_3_5 + x_3_6 + x_3_7 + x_3_8 + x_3_9 = 1
#
# _C33: x_4_0 + x_4_1 + x_4_10 + x_4_11 + x_4_12 + x_4_13 + x_4_2 + x_4_3
#  + x_4_4 + x_4_5 + x_4_6 + x_4_7 + x_4_8 + x_4_9 = 1
#
# _C34: x_5_0 + x_5_1 + x_5_10 + x_5_11 + x_5_12 + x_5_13 + x_5_2 + x_5_3
#  + x_5_4 + x_5_5 + x_5_6 + x_5_7 + x_5_8 + x_5_9 = 1
#
# _C35: x_6_0 + x_6_1 + x_6_10 + x_6_11 + x_6_12 + x_6_13 + x_6_2 + x_6_3
#  + x_6_4 + x_6_5 + x_6_6 + x_6_7 + x_6_8 + x_6_9 = 1
#
# _C36: x_7_0 + x_7_1 + x_7_10 + x_7_11 + x_7_12 + x_7_13 + x_7_2 + x_7_3
#  + x_7_4 + x_7_5 + x_7_6 + x_7_7 + x_7_8 + x_7_9 = 1
#
# _C37: x_8_0 + x_8_1 + x_8_10 + x_8_11 + x_8_12 + x_8_13 + x_8_2 + x_8_3
#  + x_8_4 + x_8_5 + x_8_6 + x_8_7 + x_8_8 + x_8_9 = 1
#
# _C38: x_9_0 + x_9_1 + x_9_10 + x_9_11 + x_9_12 + x_9_13 + x_9_2 + x_9_3
#  + x_9_4 + x_9_5 + x_9_6 + x_9_7 + x_9_8 + x_9_9 = 1
#
# _C39: x_10_0 + x_10_1 + x_10_10 + x_10_11 + x_10_12 + x_10_13 + x_10_2
#  + x_10_3 + x_10_4 + x_10_5 + x_10_6 + x_10_7 + x_10_8 + x_10_9 = 1
#
# _C40: x_11_0 + x_11_1 + x_11_10 + x_11_11 + x_11_12 + x_11_13 + x_11_2
#  + x_11_3 + x_11_4 + x_11_5 + x_11_6 + x_11_7 + x_11_8 + x_11_9 = 1
#
# _C41: x_12_0 + x_12_1 + x_12_10 + x_12_11 + x_12_12 + x_12_13 + x_12_2
#  + x_12_3 + x_12_4 + x_12_5 + x_12_6 + x_12_7 + x_12_8 + x_12_9 = 1
#
# _C42: x_13_0 + x_13_1 + x_13_10 + x_13_11 + x_13_12 + x_13_13 + x_13_2
#  + x_13_3 + x_13_4 + x_13_5 + x_13_6 + x_13_7 + x_13_8 + x_13_9 = 1
#
# _C43: 0 u_1 + 14 x_1_1 <= 13
#
# _C44: u_1 - u_2 + 14 x_2_1 <= 13
#
# _C45: u_1 - u_3 + 14 x_3_1 <= 13
#
# _C46: u_1 - u_4 + 14 x_4_1 <= 13
#
# _C47: u_1 - u_5 + 14 x_5_1 <= 13
#
# _C48: u_1 - u_6 + 14 x_6_1 <= 13
#
# _C49: u_1 - u_7 + 14 x_7_1 <= 13
#
# _C50: u_1 - u_8 + 14 x_8_1 <= 13
#
# _C51: u_1 - u_9 + 14 x_9_1 <= 13
#
# _C52: u_1 - u_10 + 14 x_10_1 <= 13
#
# _C53: u_1 - u_11 + 14 x_11_1 <= 13
#
# _C54: u_1 - u_12 + 14 x_12_1 <= 13
#
# _C55: u_1 - u_13 + 14 x_13_1 <= 13
#
# _C56: - u_1 + u_2 + 14 x_1_2 <= 13
#
# _C57: 0 u_2 + 14 x_2_2 <= 13
#
# _C58: u_2 - u_3 + 14 x_3_2 <= 13
#
# _C59: u_2 - u_4 + 14 x_4_2 <= 13
#
# _C60: u_2 - u_5 + 14 x_5_2 <= 13
#
# _C61: u_2 - u_6 + 14 x_6_2 <= 13
#
# _C62: u_2 - u_7 + 14 x_7_2 <= 13
#
# _C63: u_2 - u_8 + 14 x_8_2 <= 13
#
# _C64: u_2 - u_9 + 14 x_9_2 <= 13
#
# _C65: - u_10 + u_2 + 14 x_10_2 <= 13
#
# _C66: - u_11 + u_2 + 14 x_11_2 <= 13
#
# _C67: - u_12 + u_2 + 14 x_12_2 <= 13
#
# _C68: - u_13 + u_2 + 14 x_13_2 <= 13
#
# _C69: - u_1 + u_3 + 14 x_1_3 <= 13
#
# _C70: - u_2 + u_3 + 14 x_2_3 <= 13
#
# _C71: 0 u_3 + 14 x_3_3 <= 13
#
# _C72: u_3 - u_4 + 14 x_4_3 <= 13
#
# _C73: u_3 - u_5 + 14 x_5_3 <= 13
#
# _C74: u_3 - u_6 + 14 x_6_3 <= 13
#
# _C75: u_3 - u_7 + 14 x_7_3 <= 13
#
# _C76: u_3 - u_8 + 14 x_8_3 <= 13
#
# _C77: u_3 - u_9 + 14 x_9_3 <= 13
#
# _C78: - u_10 + u_3 + 14 x_10_3 <= 13
#
# _C79: - u_11 + u_3 + 14 x_11_3 <= 13
#
# _C80: - u_12 + u_3 + 14 x_12_3 <= 13
#
# _C81: - u_13 + u_3 + 14 x_13_3 <= 13
#
# _C82: - u_1 + u_4 + 14 x_1_4 <= 13
#
# _C83: - u_2 + u_4 + 14 x_2_4 <= 13
#
# _C84: - u_3 + u_4 + 14 x_3_4 <= 13
#
# _C85: 0 u_4 + 14 x_4_4 <= 13
#
# _C86: u_4 - u_5 + 14 x_5_4 <= 13
#
# _C87: u_4 - u_6 + 14 x_6_4 <= 13
#
# _C88: u_4 - u_7 + 14 x_7_4 <= 13
#
# _C89: u_4 - u_8 + 14 x_8_4 <= 13
#
# _C90: u_4 - u_9 + 14 x_9_4 <= 13
#
# _C91: - u_10 + u_4 + 14 x_10_4 <= 13
#
# _C92: - u_11 + u_4 + 14 x_11_4 <= 13
#
# _C93: - u_12 + u_4 + 14 x_12_4 <= 13
#
# _C94: - u_13 + u_4 + 14 x_13_4 <= 13
#
# _C95: - u_1 + u_5 + 14 x_1_5 <= 13
#
# _C96: - u_2 + u_5 + 14 x_2_5 <= 13
#
# _C97: - u_3 + u_5 + 14 x_3_5 <= 13
#
# _C98: - u_4 + u_5 + 14 x_4_5 <= 13
#
# _C99: 0 u_5 + 14 x_5_5 <= 13
#
# _C100: u_5 - u_6 + 14 x_6_5 <= 13
#
# _C101: u_5 - u_7 + 14 x_7_5 <= 13
#
# _C102: u_5 - u_8 + 14 x_8_5 <= 13
#
# _C103: u_5 - u_9 + 14 x_9_5 <= 13
#
# _C104: - u_10 + u_5 + 14 x_10_5 <= 13
#
# _C105: - u_11 + u_5 + 14 x_11_5 <= 13
#
# _C106: - u_12 + u_5 + 14 x_12_5 <= 13
#
# _C107: - u_13 + u_5 + 14 x_13_5 <= 13
#
# _C108: - u_1 + u_6 + 14 x_1_6 <= 13
#
# _C109: - u_2 + u_6 + 14 x_2_6 <= 13
#
# _C110: - u_3 + u_6 + 14 x_3_6 <= 13
#
# _C111: - u_4 + u_6 + 14 x_4_6 <= 13
#
# _C112: - u_5 + u_6 + 14 x_5_6 <= 13
#
# _C113: 0 u_6 + 14 x_6_6 <= 13
#
# _C114: u_6 - u_7 + 14 x_7_6 <= 13
#
# _C115: u_6 - u_8 + 14 x_8_6 <= 13
#
# _C116: u_6 - u_9 + 14 x_9_6 <= 13
#
# _C117: - u_10 + u_6 + 14 x_10_6 <= 13
#
# _C118: - u_11 + u_6 + 14 x_11_6 <= 13
#
# _C119: - u_12 + u_6 + 14 x_12_6 <= 13
#
# _C120: - u_13 + u_6 + 14 x_13_6 <= 13
#
# _C121: - u_1 + u_7 + 14 x_1_7 <= 13
#
# _C122: - u_2 + u_7 + 14 x_2_7 <= 13
#
# _C123: - u_3 + u_7 + 14 x_3_7 <= 13
#
# _C124: - u_4 + u_7 + 14 x_4_7 <= 13
#
# _C125: - u_5 + u_7 + 14 x_5_7 <= 13
#
# _C126: - u_6 + u_7 + 14 x_6_7 <= 13
#
# _C127: 0 u_7 + 14 x_7_7 <= 13
#
# _C128: u_7 - u_8 + 14 x_8_7 <= 13
#
# _C129: u_7 - u_9 + 14 x_9_7 <= 13
#
# _C130: - u_10 + u_7 + 14 x_10_7 <= 13
#
# _C131: - u_11 + u_7 + 14 x_11_7 <= 13
#
# _C132: - u_12 + u_7 + 14 x_12_7 <= 13
#
# _C133: - u_13 + u_7 + 14 x_13_7 <= 13
#
# _C134: - u_1 + u_8 + 14 x_1_8 <= 13
#
# _C135: - u_2 + u_8 + 14 x_2_8 <= 13
#
# _C136: - u_3 + u_8 + 14 x_3_8 <= 13
#
# _C137: - u_4 + u_8 + 14 x_4_8 <= 13
#
# _C138: - u_5 + u_8 + 14 x_5_8 <= 13
#
# _C139: - u_6 + u_8 + 14 x_6_8 <= 13
#
# _C140: - u_7 + u_8 + 14 x_7_8 <= 13
#
# _C141: 0 u_8 + 14 x_8_8 <= 13
#
# _C142: u_8 - u_9 + 14 x_9_8 <= 13
#
# _C143: - u_10 + u_8 + 14 x_10_8 <= 13
#
# _C144: - u_11 + u_8 + 14 x_11_8 <= 13
#
# _C145: - u_12 + u_8 + 14 x_12_8 <= 13
#
# _C146: - u_13 + u_8 + 14 x_13_8 <= 13
#
# _C147: - u_1 + u_9 + 14 x_1_9 <= 13
#
# _C148: - u_2 + u_9 + 14 x_2_9 <= 13
#
# _C149: - u_3 + u_9 + 14 x_3_9 <= 13
#
# _C150: - u_4 + u_9 + 14 x_4_9 <= 13
#
# _C151: - u_5 + u_9 + 14 x_5_9 <= 13
#
# _C152: - u_6 + u_9 + 14 x_6_9 <= 13
#
# _C153: - u_7 + u_9 + 14 x_7_9 <= 13
#
# _C154: - u_8 + u_9 + 14 x_8_9 <= 13
#
# _C155: 0 u_9 + 14 x_9_9 <= 13
#
# _C156: - u_10 + u_9 + 14 x_10_9 <= 13
#
# _C157: - u_11 + u_9 + 14 x_11_9 <= 13
#
# _C158: - u_12 + u_9 + 14 x_12_9 <= 13
#
# _C159: - u_13 + u_9 + 14 x_13_9 <= 13
#
# _C160: - u_1 + u_10 + 14 x_1_10 <= 13
#
# _C161: u_10 - u_2 + 14 x_2_10 <= 13
#
# _C162: u_10 - u_3 + 14 x_3_10 <= 13
#
# _C163: u_10 - u_4 + 14 x_4_10 <= 13
#
# _C164: u_10 - u_5 + 14 x_5_10 <= 13
#
# _C165: u_10 - u_6 + 14 x_6_10 <= 13
#
# _C166: u_10 - u_7 + 14 x_7_10 <= 13
#
# _C167: u_10 - u_8 + 14 x_8_10 <= 13
#
# _C168: u_10 - u_9 + 14 x_9_10 <= 13
#
# _C169: 0 u_10 + 14 x_10_10 <= 13
#
# _C170: u_10 - u_11 + 14 x_11_10 <= 13
#
# _C171: u_10 - u_12 + 14 x_12_10 <= 13
#
# _C172: u_10 - u_13 + 14 x_13_10 <= 13
#
# _C173: - u_1 + u_11 + 14 x_1_11 <= 13
#
# _C174: u_11 - u_2 + 14 x_2_11 <= 13
#
# _C175: u_11 - u_3 + 14 x_3_11 <= 13
#
# _C176: u_11 - u_4 + 14 x_4_11 <= 13
#
# _C177: u_11 - u_5 + 14 x_5_11 <= 13
#
# _C178: u_11 - u_6 + 14 x_6_11 <= 13
#
# _C179: u_11 - u_7 + 14 x_7_11 <= 13
#
# _C180: u_11 - u_8 + 14 x_8_11 <= 13
#
# _C181: u_11 - u_9 + 14 x_9_11 <= 13
#
# _C182: - u_10 + u_11 + 14 x_10_11 <= 13
#
# _C183: 0 u_11 + 14 x_11_11 <= 13
#
# _C184: u_11 - u_12 + 14 x_12_11 <= 13
#
# _C185: u_11 - u_13 + 14 x_13_11 <= 13
#
# _C186: - u_1 + u_12 + 14 x_1_12 <= 13
#
# _C187: u_12 - u_2 + 14 x_2_12 <= 13
#
# _C188: u_12 - u_3 + 14 x_3_12 <= 13
#
# _C189: u_12 - u_4 + 14 x_4_12 <= 13
#
# _C190: u_12 - u_5 + 14 x_5_12 <= 13
#
# _C191: u_12 - u_6 + 14 x_6_12 <= 13
#
# _C192: u_12 - u_7 + 14 x_7_12 <= 13
#
# _C193: u_12 - u_8 + 14 x_8_12 <= 13
#
# _C194: u_12 - u_9 + 14 x_9_12 <= 13
#
# _C195: - u_10 + u_12 + 14 x_10_12 <= 13
#
# _C196: - u_11 + u_12 + 14 x_11_12 <= 13
#
# _C197: 0 u_12 + 14 x_12_12 <= 13
#
# _C198: u_12 - u_13 + 14 x_13_12 <= 13
#
# _C199: - u_1 + u_13 + 14 x_1_13 <= 13
#
# _C200: u_13 - u_2 + 14 x_2_13 <= 13
#
# _C201: u_13 - u_3 + 14 x_3_13 <= 13
#
# _C202: u_13 - u_4 + 14 x_4_13 <= 13
#
# _C203: u_13 - u_5 + 14 x_5_13 <= 13
#
# _C204: u_13 - u_6 + 14 x_6_13 <= 13
#
# _C205: u_13 - u_7 + 14 x_7_13 <= 13
#
# _C206: u_13 - u_8 + 14 x_8_13 <= 13
#
# _C207: u_13 - u_9 + 14 x_9_13 <= 13
#
# _C208: - u_10 + u_13 + 14 x_10_13 <= 13
#
# _C209: - u_11 + u_13 + 14 x_11_13 <= 13
#
# _C210: - u_12 + u_13 + 14 x_12_13 <= 13
#
# _C211: 0 u_13 + 14 x_13_13 <= 13
#
# VARIABLES
# 2 <= u_1 <= 14 Integer
# 2 <= u_10 <= 14 Integer
# 2 <= u_11 <= 14 Integer
# 2 <= u_12 <= 14 Integer
# 2 <= u_13 <= 14 Integer
# 2 <= u_2 <= 14 Integer
# 2 <= u_3 <= 14 Integer
# 2 <= u_4 <= 14 Integer
# 2 <= u_5 <= 14 Integer
# 2 <= u_6 <= 14 Integer
# 2 <= u_7 <= 14 Integer
# 2 <= u_8 <= 14 Integer
# 2 <= u_9 <= 14 Integer
# 0 <= x_0_0 <= 1 Integer
# 0 <= x_0_1 <= 1 Integer
# 0 <= x_0_10 <= 1 Integer
# 0 <= x_0_11 <= 1 Integer
# 0 <= x_0_12 <= 1 Integer
# 0 <= x_0_13 <= 1 Integer
# 0 <= x_0_2 <= 1 Integer
# 0 <= x_0_3 <= 1 Integer
# 0 <= x_0_4 <= 1 Integer
# 0 <= x_0_5 <= 1 Integer
# 0 <= x_0_6 <= 1 Integer
# 0 <= x_0_7 <= 1 Integer
# 0 <= x_0_8 <= 1 Integer
# 0 <= x_0_9 <= 1 Integer
# 0 <= x_10_0 <= 1 Integer
# 0 <= x_10_1 <= 1 Integer
# 0 <= x_10_10 <= 1 Integer
# 0 <= x_10_11 <= 1 Integer
# 0 <= x_10_12 <= 1 Integer
# 0 <= x_10_13 <= 1 Integer
# 0 <= x_10_2 <= 1 Integer
# 0 <= x_10_3 <= 1 Integer
# 0 <= x_10_4 <= 1 Integer
# 0 <= x_10_5 <= 1 Integer
# 0 <= x_10_6 <= 1 Integer
# 0 <= x_10_7 <= 1 Integer
# 0 <= x_10_8 <= 1 Integer
# 0 <= x_10_9 <= 1 Integer
# 0 <= x_11_0 <= 1 Integer
# 0 <= x_11_1 <= 1 Integer
# 0 <= x_11_10 <= 1 Integer
# 0 <= x_11_11 <= 1 Integer
# 0 <= x_11_12 <= 1 Integer
# 0 <= x_11_13 <= 1 Integer
# 0 <= x_11_2 <= 1 Integer
# 0 <= x_11_3 <= 1 Integer
# 0 <= x_11_4 <= 1 Integer
# 0 <= x_11_5 <= 1 Integer
# 0 <= x_11_6 <= 1 Integer
# 0 <= x_11_7 <= 1 Integer
# 0 <= x_11_8 <= 1 Integer
# 0 <= x_11_9 <= 1 Integer
# 0 <= x_12_0 <= 1 Integer
# 0 <= x_12_1 <= 1 Integer
# 0 <= x_12_10 <= 1 Integer
# 0 <= x_12_11 <= 1 Integer
# 0 <= x_12_12 <= 1 Integer
# 0 <= x_12_13 <= 1 Integer
# 0 <= x_12_2 <= 1 Integer
# 0 <= x_12_3 <= 1 Integer
# 0 <= x_12_4 <= 1 Integer
# 0 <= x_12_5 <= 1 Integer
# 0 <= x_12_6 <= 1 Integer
# 0 <= x_12_7 <= 1 Integer
# 0 <= x_12_8 <= 1 Integer
# 0 <= x_12_9 <= 1 Integer
# 0 <= x_13_0 <= 1 Integer
# 0 <= x_13_1 <= 1 Integer
# 0 <= x_13_10 <= 1 Integer
# 0 <= x_13_11 <= 1 Integer
# 0 <= x_13_12 <= 1 Integer
# 0 <= x_13_13 <= 1 Integer
# 0 <= x_13_2 <= 1 Integer
# 0 <= x_13_3 <= 1 Integer
# 0 <= x_13_4 <= 1 Integer
# 0 <= x_13_5 <= 1 Integer
# 0 <= x_13_6 <= 1 Integer
# 0 <= x_13_7 <= 1 Integer
# 0 <= x_13_8 <= 1 Integer
# 0 <= x_13_9 <= 1 Integer
# 0 <= x_1_0 <= 1 Integer
# 0 <= x_1_1 <= 1 Integer
# 0 <= x_1_10 <= 1 Integer
# 0 <= x_1_11 <= 1 Integer
# 0 <= x_1_12 <= 1 Integer
# 0 <= x_1_13 <= 1 Integer
# 0 <= x_1_2 <= 1 Integer
# 0 <= x_1_3 <= 1 Integer
# 0 <= x_1_4 <= 1 Integer
# 0 <= x_1_5 <= 1 Integer
# 0 <= x_1_6 <= 1 Integer
# 0 <= x_1_7 <= 1 Integer
# 0 <= x_1_8 <= 1 Integer
# 0 <= x_1_9 <= 1 Integer
# 0 <= x_2_0 <= 1 Integer
# 0 <= x_2_1 <= 1 Integer
# 0 <= x_2_10 <= 1 Integer
# 0 <= x_2_11 <= 1 Integer
# 0 <= x_2_12 <= 1 Integer
# 0 <= x_2_13 <= 1 Integer
# 0 <= x_2_2 <= 1 Integer
# 0 <= x_2_3 <= 1 Integer
# 0 <= x_2_4 <= 1 Integer
# 0 <= x_2_5 <= 1 Integer
# 0 <= x_2_6 <= 1 Integer
# 0 <= x_2_7 <= 1 Integer
# 0 <= x_2_8 <= 1 Integer
# 0 <= x_2_9 <= 1 Integer
# 0 <= x_3_0 <= 1 Integer
# 0 <= x_3_1 <= 1 Integer
# 0 <= x_3_10 <= 1 Integer
# 0 <= x_3_11 <= 1 Integer
# 0 <= x_3_12 <= 1 Integer
# 0 <= x_3_13 <= 1 Integer
# 0 <= x_3_2 <= 1 Integer
# 0 <= x_3_3 <= 1 Integer
# 0 <= x_3_4 <= 1 Integer
# 0 <= x_3_5 <= 1 Integer
# 0 <= x_3_6 <= 1 Integer
# 0 <= x_3_7 <= 1 Integer
# 0 <= x_3_8 <= 1 Integer
# 0 <= x_3_9 <= 1 Integer
# 0 <= x_4_0 <= 1 Integer
# 0 <= x_4_1 <= 1 Integer
# 0 <= x_4_10 <= 1 Integer
# 0 <= x_4_11 <= 1 Integer
# 0 <= x_4_12 <= 1 Integer
# 0 <= x_4_13 <= 1 Integer
# 0 <= x_4_2 <= 1 Integer
# 0 <= x_4_3 <= 1 Integer
# 0 <= x_4_4 <= 1 Integer
# 0 <= x_4_5 <= 1 Integer
# 0 <= x_4_6 <= 1 Integer
# 0 <= x_4_7 <= 1 Integer
# 0 <= x_4_8 <= 1 Integer
# 0 <= x_4_9 <= 1 Integer
# 0 <= x_5_0 <= 1 Integer
# 0 <= x_5_1 <= 1 Integer
# 0 <= x_5_10 <= 1 Integer
# 0 <= x_5_11 <= 1 Integer
# 0 <= x_5_12 <= 1 Integer
# 0 <= x_5_13 <= 1 Integer
# 0 <= x_5_2 <= 1 Integer
# 0 <= x_5_3 <= 1 Integer
# 0 <= x_5_4 <= 1 Integer
# 0 <= x_5_5 <= 1 Integer
# 0 <= x_5_6 <= 1 Integer
# 0 <= x_5_7 <= 1 Integer
# 0 <= x_5_8 <= 1 Integer
# 0 <= x_5_9 <= 1 Integer
# 0 <= x_6_0 <= 1 Integer
# 0 <= x_6_1 <= 1 Integer
# 0 <= x_6_10 <= 1 Integer
# 0 <= x_6_11 <= 1 Integer
# 0 <= x_6_12 <= 1 Integer
# 0 <= x_6_13 <= 1 Integer
# 0 <= x_6_2 <= 1 Integer
# 0 <= x_6_3 <= 1 Integer
# 0 <= x_6_4 <= 1 Integer
# 0 <= x_6_5 <= 1 Integer
# 0 <= x_6_6 <= 1 Integer
# 0 <= x_6_7 <= 1 Integer
# 0 <= x_6_8 <= 1 Integer
# 0 <= x_6_9 <= 1 Integer
# 0 <= x_7_0 <= 1 Integer
# 0 <= x_7_1 <= 1 Integer
# 0 <= x_7_10 <= 1 Integer
# 0 <= x_7_11 <= 1 Integer
# 0 <= x_7_12 <= 1 Integer
# 0 <= x_7_13 <= 1 Integer
# 0 <= x_7_2 <= 1 Integer
# 0 <= x_7_3 <= 1 Integer
# 0 <= x_7_4 <= 1 Integer
# 0 <= x_7_5 <= 1 Integer
# 0 <= x_7_6 <= 1 Integer
# 0 <= x_7_7 <= 1 Integer
# 0 <= x_7_8 <= 1 Integer
# 0 <= x_7_9 <= 1 Integer
# 0 <= x_8_0 <= 1 Integer
# 0 <= x_8_1 <= 1 Integer
# 0 <= x_8_10 <= 1 Integer
# 0 <= x_8_11 <= 1 Integer
# 0 <= x_8_12 <= 1 Integer
# 0 <= x_8_13 <= 1 Integer
# 0 <= x_8_2 <= 1 Integer
# 0 <= x_8_3 <= 1 Integer
# 0 <= x_8_4 <= 1 Integer
# 0 <= x_8_5 <= 1 Integer
# 0 <= x_8_6 <= 1 Integer
# 0 <= x_8_7 <= 1 Integer
# 0 <= x_8_8 <= 1 Integer
# 0 <= x_8_9 <= 1 Integer
# 0 <= x_9_0 <= 1 Integer
# 0 <= x_9_1 <= 1 Integer
# 0 <= x_9_10 <= 1 Integer
# 0 <= x_9_11 <= 1 Integer
# 0 <= x_9_12 <= 1 Integer
# 0 <= x_9_13 <= 1 Integer
# 0 <= x_9_2 <= 1 Integer
# 0 <= x_9_3 <= 1 Integer
# 0 <= x_9_4 <= 1 Integer
# 0 <= x_9_5 <= 1 Integer
# 0 <= x_9_6 <= 1 Integer
# 0 <= x_9_7 <= 1 Integer
# 0 <= x_9_8 <= 1 Integer
# 0 <= x_9_9 <= 1 Integer
#
# the minimal cycle length is  1100.8809750229684

# %%
# Example 6
# Consider the following 17 points.
coordinates = [(5, 171), (109, 173), (4, 255), (208, 158), (269, 11), (280, 273), (32, 0), (188, 59), (180, 208), (140, 106), (131, 276), (65, 233), (274, 62), (120, 182), (300, 234), (41, 102), (140, 226)]
# Create a corresponding graph.
g = get_graph(coordinates)
# Compute an optimal Hamiltonian path using Integer Linear Programming:
cycle = ilp(g)
print(cycle)
# Plot the resulting cycle
plot_cycle(coordinates, cycle)
# Out:
#  x_2_16 + x_3_16 + x_4_16 + x_5_16 + x_6_16 + x_7_16
#  + x_8_16 + x_9_16 = 1
#
# _C35: x_0_0 + x_0_1 + x_0_10 + x_0_11 + x_0_12 + x_0_13 + x_0_14 + x_0_15
#  + x_0_16 + x_0_2 + x_0_3 + x_0_4 + x_0_5 + x_0_6 + x_0_7 + x_0_8 + x_0_9 = 1
#
# _C36: x_1_0 + x_1_1 + x_1_10 + x_1_11 + x_1_12 + x_1_13 + x_1_14 + x_1_15
#  + x_1_16 + x_1_2 + x_1_3 + x_1_4 + x_1_5 + x_1_6 + x_1_7 + x_1_8 + x_1_9 = 1
#
# _C37: x_2_0 + x_2_1 + x_2_10 + x_2_11 + x_2_12 + x_2_13 + x_2_14 + x_2_15
#  + x_2_16 + x_2_2 + x_2_3 + x_2_4 + x_2_5 + x_2_6 + x_2_7 + x_2_8 + x_2_9 = 1
#
# _C38: x_3_0 + x_3_1 + x_3_10 + x_3_11 + x_3_12 + x_3_13 + x_3_14 + x_3_15
#  + x_3_16 + x_3_2 + x_3_3 + x_3_4 + x_3_5 + x_3_6 + x_3_7 + x_3_8 + x_3_9 = 1
#
# _C39: x_4_0 + x_4_1 + x_4_10 + x_4_11 + x_4_12 + x_4_13 + x_4_14 + x_4_15
#  + x_4_16 + x_4_2 + x_4_3 + x_4_4 + x_4_5 + x_4_6 + x_4_7 + x_4_8 + x_4_9 = 1
#
# _C40: x_5_0 + x_5_1 + x_5_10 + x_5_11 + x_5_12 + x_5_13 + x_5_14 + x_5_15
#  + x_5_16 + x_5_2 + x_5_3 + x_5_4 + x_5_5 + x_5_6 + x_5_7 + x_5_8 + x_5_9 = 1
#
# _C41: x_6_0 + x_6_1 + x_6_10 + x_6_11 + x_6_12 + x_6_13 + x_6_14 + x_6_15
#  + x_6_16 + x_6_2 + x_6_3 + x_6_4 + x_6_5 + x_6_6 + x_6_7 + x_6_8 + x_6_9 = 1
#
# _C42: x_7_0 + x_7_1 + x_7_10 + x_7_11 + x_7_12 + x_7_13 + x_7_14 + x_7_15
#  + x_7_16 + x_7_2 + x_7_3 + x_7_4 + x_7_5 + x_7_6 + x_7_7 + x_7_8 + x_7_9 = 1
#
# _C43: x_8_0 + x_8_1 + x_8_10 + x_8_11 + x_8_12 + x_8_13 + x_8_14 + x_8_15
#  + x_8_16 + x_8_2 + x_8_3 + x_8_4 + x_8_5 + x_8_6 + x_8_7 + x_8_8 + x_8_9 = 1
#
# _C44: x_9_0 + x_9_1 + x_9_10 + x_9_11 + x_9_12 + x_9_13 + x_9_14 + x_9_15
#  + x_9_16 + x_9_2 + x_9_3 + x_9_4 + x_9_5 + x_9_6 + x_9_7 + x_9_8 + x_9_9 = 1
#
# _C45: x_10_0 + x_10_1 + x_10_10 + x_10_11 + x_10_12 + x_10_13 + x_10_14
#  + x_10_15 + x_10_16 + x_10_2 + x_10_3 + x_10_4 + x_10_5 + x_10_6 + x_10_7
#  + x_10_8 + x_10_9 = 1
#
# _C46: x_11_0 + x_11_1 + x_11_10 + x_11_11 + x_11_12 + x_11_13 + x_11_14
#  + x_11_15 + x_11_16 + x_11_2 + x_11_3 + x_11_4 + x_11_5 + x_11_6 + x_11_7
#  + x_11_8 + x_11_9 = 1
#
# _C47: x_12_0 + x_12_1 + x_12_10 + x_12_11 + x_12_12 + x_12_13 + x_12_14
#  + x_12_15 + x_12_16 + x_12_2 + x_12_3 + x_12_4 + x_12_5 + x_12_6 + x_12_7
#  + x_12_8 + x_12_9 = 1
#
# _C48: x_13_0 + x_13_1 + x_13_10 + x_13_11 + x_13_12 + x_13_13 + x_13_14
#  + x_13_15 + x_13_16 + x_13_2 + x_13_3 + x_13_4 + x_13_5 + x_13_6 + x_13_7
#  + x_13_8 + x_13_9 = 1
#
# _C49: x_14_0 + x_14_1 + x_14_10 + x_14_11 + x_14_12 + x_14_13 + x_14_14
#  + x_14_15 + x_14_16 + x_14_2 + x_14_3 + x_14_4 + x_14_5 + x_14_6 + x_14_7
#  + x_14_8 + x_14_9 = 1
#
# _C50: x_15_0 + x_15_1 + x_15_10 + x_15_11 + x_15_12 + x_15_13 + x_15_14
#  + x_15_15 + x_15_16 + x_15_2 + x_15_3 + x_15_4 + x_15_5 + x_15_6 + x_15_7
#  + x_15_8 + x_15_9 = 1
#
# _C51: x_16_0 + x_16_1 + x_16_10 + x_16_11 + x_16_12 + x_16_13 + x_16_14
#  + x_16_15 + x_16_16 + x_16_2 + x_16_3 + x_16_4 + x_16_5 + x_16_6 + x_16_7
#  + x_16_8 + x_16_9 = 1
#
# _C52: 0 u_1 + 17 x_1_1 <= 16
#
# _C53: u_1 - u_2 + 17 x_2_1 <= 16
#
# _C54: u_1 - u_3 + 17 x_3_1 <= 16
#
# _C55: u_1 - u_4 + 17 x_4_1 <= 16
#
# _C56: u_1 - u_5 + 17 x_5_1 <= 16
#
# _C57: u_1 - u_6 + 17 x_6_1 <= 16
#
# _C58: u_1 - u_7 + 17 x_7_1 <= 16
#
# _C59: u_1 - u_8 + 17 x_8_1 <= 16
#
# _C60: u_1 - u_9 + 17 x_9_1 <= 16
#
# _C61: u_1 - u_10 + 17 x_10_1 <= 16
#
# _C62: u_1 - u_11 + 17 x_11_1 <= 16
#
# _C63: u_1 - u_12 + 17 x_12_1 <= 16
#
# _C64: u_1 - u_13 + 17 x_13_1 <= 16
#
# _C65: u_1 - u_14 + 17 x_14_1 <= 16
#
# _C66: u_1 - u_15 + 17 x_15_1 <= 16
#
# _C67: u_1 - u_16 + 17 x_16_1 <= 16
#
# _C68: - u_1 + u_2 + 17 x_1_2 <= 16
#
# _C69: 0 u_2 + 17 x_2_2 <= 16
#
# _C70: u_2 - u_3 + 17 x_3_2 <= 16
#
# _C71: u_2 - u_4 + 17 x_4_2 <= 16
#
# _C72: u_2 - u_5 + 17 x_5_2 <= 16
#
# _C73: u_2 - u_6 + 17 x_6_2 <= 16
#
# _C74: u_2 - u_7 + 17 x_7_2 <= 16
#
# _C75: u_2 - u_8 + 17 x_8_2 <= 16
#
# _C76: u_2 - u_9 + 17 x_9_2 <= 16
#
# _C77: - u_10 + u_2 + 17 x_10_2 <= 16
#
# _C78: - u_11 + u_2 + 17 x_11_2 <= 16
#
# _C79: - u_12 + u_2 + 17 x_12_2 <= 16
#
# _C80: - u_13 + u_2 + 17 x_13_2 <= 16
#
# _C81: - u_14 + u_2 + 17 x_14_2 <= 16
#
# _C82: - u_15 + u_2 + 17 x_15_2 <= 16
#
# _C83: - u_16 + u_2 + 17 x_16_2 <= 16
#
# _C84: - u_1 + u_3 + 17 x_1_3 <= 16
#
# _C85: - u_2 + u_3 + 17 x_2_3 <= 16
#
# _C86: 0 u_3 + 17 x_3_3 <= 16
#
# _C87: u_3 - u_4 + 17 x_4_3 <= 16
#
# _C88: u_3 - u_5 + 17 x_5_3 <= 16
#
# _C89: u_3 - u_6 + 17 x_6_3 <= 16
#
# _C90: u_3 - u_7 + 17 x_7_3 <= 16
#
# _C91: u_3 - u_8 + 17 x_8_3 <= 16
#
# _C92: u_3 - u_9 + 17 x_9_3 <= 16
#
# _C93: - u_10 + u_3 + 17 x_10_3 <= 16
#
# _C94: - u_11 + u_3 + 17 x_11_3 <= 16
#
# _C95: - u_12 + u_3 + 17 x_12_3 <= 16
#
# _C96: - u_13 + u_3 + 17 x_13_3 <= 16
#
# _C97: - u_14 + u_3 + 17 x_14_3 <= 16
#
# _C98: - u_15 + u_3 + 17 x_15_3 <= 16
#
# _C99: - u_16 + u_3 + 17 x_16_3 <= 16
#
# _C100: - u_1 + u_4 + 17 x_1_4 <= 16
#
# _C101: - u_2 + u_4 + 17 x_2_4 <= 16
#
# _C102: - u_3 + u_4 + 17 x_3_4 <= 16
#
# _C103: 0 u_4 + 17 x_4_4 <= 16
#
# _C104: u_4 - u_5 + 17 x_5_4 <= 16
#
# _C105: u_4 - u_6 + 17 x_6_4 <= 16
#
# _C106: u_4 - u_7 + 17 x_7_4 <= 16
#
# _C107: u_4 - u_8 + 17 x_8_4 <= 16
#
# _C108: u_4 - u_9 + 17 x_9_4 <= 16
#
# _C109: - u_10 + u_4 + 17 x_10_4 <= 16
#
# _C110: - u_11 + u_4 + 17 x_11_4 <= 16
#
# _C111: - u_12 + u_4 + 17 x_12_4 <= 16
#
# _C112: - u_13 + u_4 + 17 x_13_4 <= 16
#
# _C113: - u_14 + u_4 + 17 x_14_4 <= 16
#
# _C114: - u_15 + u_4 + 17 x_15_4 <= 16
#
# _C115: - u_16 + u_4 + 17 x_16_4 <= 16
#
# _C116: - u_1 + u_5 + 17 x_1_5 <= 16
#
# _C117: - u_2 + u_5 + 17 x_2_5 <= 16
#
# _C118: - u_3 + u_5 + 17 x_3_5 <= 16
#
# _C119: - u_4 + u_5 + 17 x_4_5 <= 16
#
# _C120: 0 u_5 + 17 x_5_5 <= 16
#
# _C121: u_5 - u_6 + 17 x_6_5 <= 16
#
# _C122: u_5 - u_7 + 17 x_7_5 <= 16
#
# _C123: u_5 - u_8 + 17 x_8_5 <= 16
#
# _C124: u_5 - u_9 + 17 x_9_5 <= 16
#
# _C125: - u_10 + u_5 + 17 x_10_5 <= 16
#
# _C126: - u_11 + u_5 + 17 x_11_5 <= 16
#
# _C127: - u_12 + u_5 + 17 x_12_5 <= 16
#
# _C128: - u_13 + u_5 + 17 x_13_5 <= 16
#
# _C129: - u_14 + u_5 + 17 x_14_5 <= 16
#
# _C130: - u_15 + u_5 + 17 x_15_5 <= 16
#
# _C131: - u_16 + u_5 + 17 x_16_5 <= 16
#
# _C132: - u_1 + u_6 + 17 x_1_6 <= 16
#
# _C133: - u_2 + u_6 + 17 x_2_6 <= 16
#
# _C134: - u_3 + u_6 + 17 x_3_6 <= 16
#
# _C135: - u_4 + u_6 + 17 x_4_6 <= 16
#
# _C136: - u_5 + u_6 + 17 x_5_6 <= 16
#
# _C137: 0 u_6 + 17 x_6_6 <= 16
#
# _C138: u_6 - u_7 + 17 x_7_6 <= 16
#
# _C139: u_6 - u_8 + 17 x_8_6 <= 16
#
# _C140: u_6 - u_9 + 17 x_9_6 <= 16
#
# _C141: - u_10 + u_6 + 17 x_10_6 <= 16
#
# _C142: - u_11 + u_6 + 17 x_11_6 <= 16
#
# _C143: - u_12 + u_6 + 17 x_12_6 <= 16
#
# _C144: - u_13 + u_6 + 17 x_13_6 <= 16
#
# _C145: - u_14 + u_6 + 17 x_14_6 <= 16
#
# _C146: - u_15 + u_6 + 17 x_15_6 <= 16
#
# _C147: - u_16 + u_6 + 17 x_16_6 <= 16
#
# _C148: - u_1 + u_7 + 17 x_1_7 <= 16
#
# _C149: - u_2 + u_7 + 17 x_2_7 <= 16
#
# _C150: - u_3 + u_7 + 17 x_3_7 <= 16
#
# _C151: - u_4 + u_7 + 17 x_4_7 <= 16
#
# _C152: - u_5 + u_7 + 17 x_5_7 <= 16
#
# _C153: - u_6 + u_7 + 17 x_6_7 <= 16
#
# _C154: 0 u_7 + 17 x_7_7 <= 16
#
# _C155: u_7 - u_8 + 17 x_8_7 <= 16
#
# _C156: u_7 - u_9 + 17 x_9_7 <= 16
#
# _C157: - u_10 + u_7 + 17 x_10_7 <= 16
#
# _C158: - u_11 + u_7 + 17 x_11_7 <= 16
#
# _C159: - u_12 + u_7 + 17 x_12_7 <= 16
#
# _C160: - u_13 + u_7 + 17 x_13_7 <= 16
#
# _C161: - u_14 + u_7 + 17 x_14_7 <= 16
#
# _C162: - u_15 + u_7 + 17 x_15_7 <= 16
#
# _C163: - u_16 + u_7 + 17 x_16_7 <= 16
#
# _C164: - u_1 + u_8 + 17 x_1_8 <= 16
#
# _C165: - u_2 + u_8 + 17 x_2_8 <= 16
#
# _C166: - u_3 + u_8 + 17 x_3_8 <= 16
#
# _C167: - u_4 + u_8 + 17 x_4_8 <= 16
#
# _C168: - u_5 + u_8 + 17 x_5_8 <= 16
#
# _C169: - u_6 + u_8 + 17 x_6_8 <= 16
#
# _C170: - u_7 + u_8 + 17 x_7_8 <= 16
#
# _C171: 0 u_8 + 17 x_8_8 <= 16
#
# _C172: u_8 - u_9 + 17 x_9_8 <= 16
#
# _C173: - u_10 + u_8 + 17 x_10_8 <= 16
#
# _C174: - u_11 + u_8 + 17 x_11_8 <= 16
#
# _C175: - u_12 + u_8 + 17 x_12_8 <= 16
#
# _C176: - u_13 + u_8 + 17 x_13_8 <= 16
#
# _C177: - u_14 + u_8 + 17 x_14_8 <= 16
#
# _C178: - u_15 + u_8 + 17 x_15_8 <= 16
#
# _C179: - u_16 + u_8 + 17 x_16_8 <= 16
#
# _C180: - u_1 + u_9 + 17 x_1_9 <= 16
#
# _C181: - u_2 + u_9 + 17 x_2_9 <= 16
#
# _C182: - u_3 + u_9 + 17 x_3_9 <= 16
#
# _C183: - u_4 + u_9 + 17 x_4_9 <= 16
#
# _C184: - u_5 + u_9 + 17 x_5_9 <= 16
#
# _C185: - u_6 + u_9 + 17 x_6_9 <= 16
#
# _C186: - u_7 + u_9 + 17 x_7_9 <= 16
#
# _C187: - u_8 + u_9 + 17 x_8_9 <= 16
#
# _C188: 0 u_9 + 17 x_9_9 <= 16
#
# _C189: - u_10 + u_9 + 17 x_10_9 <= 16
#
# _C190: - u_11 + u_9 + 17 x_11_9 <= 16
#
# _C191: - u_12 + u_9 + 17 x_12_9 <= 16
#
# _C192: - u_13 + u_9 + 17 x_13_9 <= 16
#
# _C193: - u_14 + u_9 + 17 x_14_9 <= 16
#
# _C194: - u_15 + u_9 + 17 x_15_9 <= 16
#
# _C195: - u_16 + u_9 + 17 x_16_9 <= 16
#
# _C196: - u_1 + u_10 + 17 x_1_10 <= 16
#
# _C197: u_10 - u_2 + 17 x_2_10 <= 16
#
# _C198: u_10 - u_3 + 17 x_3_10 <= 16
#
# _C199: u_10 - u_4 + 17 x_4_10 <= 16
#
# _C200: u_10 - u_5 + 17 x_5_10 <= 16
#
# _C201: u_10 - u_6 + 17 x_6_10 <= 16
#
# _C202: u_10 - u_7 + 17 x_7_10 <= 16
#
# _C203: u_10 - u_8 + 17 x_8_10 <= 16
#
# _C204: u_10 - u_9 + 17 x_9_10 <= 16
#
# _C205: 0 u_10 + 17 x_10_10 <= 16
#
# _C206: u_10 - u_11 + 17 x_11_10 <= 16
#
# _C207: u_10 - u_12 + 17 x_12_10 <= 16
#
# _C208: u_10 - u_13 + 17 x_13_10 <= 16
#
# _C209: u_10 - u_14 + 17 x_14_10 <= 16
#
# _C210: u_10 - u_15 + 17 x_15_10 <= 16
#
# _C211: u_10 - u_16 + 17 x_16_10 <= 16
#
# _C212: - u_1 + u_11 + 17 x_1_11 <= 16
#
# _C213: u_11 - u_2 + 17 x_2_11 <= 16
#
# _C214: u_11 - u_3 + 17 x_3_11 <= 16
#
# _C215: u_11 - u_4 + 17 x_4_11 <= 16
#
# _C216: u_11 - u_5 + 17 x_5_11 <= 16
#
# _C217: u_11 - u_6 + 17 x_6_11 <= 16
#
# _C218: u_11 - u_7 + 17 x_7_11 <= 16
#
# _C219: u_11 - u_8 + 17 x_8_11 <= 16
#
# _C220: u_11 - u_9 + 17 x_9_11 <= 16
#
# _C221: - u_10 + u_11 + 17 x_10_11 <= 16
#
# _C222: 0 u_11 + 17 x_11_11 <= 16
#
# _C223: u_11 - u_12 + 17 x_12_11 <= 16
#
# _C224: u_11 - u_13 + 17 x_13_11 <= 16
#
# _C225: u_11 - u_14 + 17 x_14_11 <= 16
#
# _C226: u_11 - u_15 + 17 x_15_11 <= 16
#
# _C227: u_11 - u_16 + 17 x_16_11 <= 16
#
# _C228: - u_1 + u_12 + 17 x_1_12 <= 16
#
# _C229: u_12 - u_2 + 17 x_2_12 <= 16
#
# _C230: u_12 - u_3 + 17 x_3_12 <= 16
#
# _C231: u_12 - u_4 + 17 x_4_12 <= 16
#
# _C232: u_12 - u_5 + 17 x_5_12 <= 16
#
# _C233: u_12 - u_6 + 17 x_6_12 <= 16
#
# _C234: u_12 - u_7 + 17 x_7_12 <= 16
#
# _C235: u_12 - u_8 + 17 x_8_12 <= 16
#
# _C236: u_12 - u_9 + 17 x_9_12 <= 16
#
# _C237: - u_10 + u_12 + 17 x_10_12 <= 16
#
# _C238: - u_11 + u_12 + 17 x_11_12 <= 16
#
# _C239: 0 u_12 + 17 x_12_12 <= 16
#
# _C240: u_12 - u_13 + 17 x_13_12 <= 16
#
# _C241: u_12 - u_14 + 17 x_14_12 <= 16
#
# _C242: u_12 - u_15 + 17 x_15_12 <= 16
#
# _C243: u_12 - u_16 + 17 x_16_12 <= 16
#
# _C244: - u_1 + u_13 + 17 x_1_13 <= 16
#
# _C245: u_13 - u_2 + 17 x_2_13 <= 16
#
# _C246: u_13 - u_3 + 17 x_3_13 <= 16
#
# _C247: u_13 - u_4 + 17 x_4_13 <= 16
#
# _C248: u_13 - u_5 + 17 x_5_13 <= 16
#
# _C249: u_13 - u_6 + 17 x_6_13 <= 16
#
# _C250: u_13 - u_7 + 17 x_7_13 <= 16
#
# _C251: u_13 - u_8 + 17 x_8_13 <= 16
#
# _C252: u_13 - u_9 + 17 x_9_13 <= 16
#
# _C253: - u_10 + u_13 + 17 x_10_13 <= 16
#
# _C254: - u_11 + u_13 + 17 x_11_13 <= 16
#
# _C255: - u_12 + u_13 + 17 x_12_13 <= 16
#
# _C256: 0 u_13 + 17 x_13_13 <= 16
#
# _C257: u_13 - u_14 + 17 x_14_13 <= 16
#
# _C258: u_13 - u_15 + 17 x_15_13 <= 16
#
# _C259: u_13 - u_16 + 17 x_16_13 <= 16
#
# _C260: - u_1 + u_14 + 17 x_1_14 <= 16
#
# _C261: u_14 - u_2 + 17 x_2_14 <= 16
#
# _C262: u_14 - u_3 + 17 x_3_14 <= 16
#
# _C263: u_14 - u_4 + 17 x_4_14 <= 16
#
# _C264: u_14 - u_5 + 17 x_5_14 <= 16
#
# _C265: u_14 - u_6 + 17 x_6_14 <= 16
#
# _C266: u_14 - u_7 + 17 x_7_14 <= 16
#
# _C267: u_14 - u_8 + 17 x_8_14 <= 16
#
# _C268: u_14 - u_9 + 17 x_9_14 <= 16
#
# _C269: - u_10 + u_14 + 17 x_10_14 <= 16
#
# _C270: - u_11 + u_14 + 17 x_11_14 <= 16
#
# _C271: - u_12 + u_14 + 17 x_12_14 <= 16
#
# _C272: - u_13 + u_14 + 17 x_13_14 <= 16
#
# _C273: 0 u_14 + 17 x_14_14 <= 16
#
# _C274: u_14 - u_15 + 17 x_15_14 <= 16
#
# _C275: u_14 - u_16 + 17 x_16_14 <= 16
#
# _C276: - u_1 + u_15 + 17 x_1_15 <= 16
#
# _C277: u_15 - u_2 + 17 x_2_15 <= 16
#
# _C278: u_15 - u_3 + 17 x_3_15 <= 16
#
# _C279: u_15 - u_4 + 17 x_4_15 <= 16
#
# _C280: u_15 - u_5 + 17 x_5_15 <= 16
#
# _C281: u_15 - u_6 + 17 x_6_15 <= 16
#
# _C282: u_15 - u_7 + 17 x_7_15 <= 16
#
# _C283: u_15 - u_8 + 17 x_8_15 <= 16
#
# _C284: u_15 - u_9 + 17 x_9_15 <= 16
#
# _C285: - u_10 + u_15 + 17 x_10_15 <= 16
#
# _C286: - u_11 + u_15 + 17 x_11_15 <= 16
#
# _C287: - u_12 + u_15 + 17 x_12_15 <= 16
#
# _C288: - u_13 + u_15 + 17 x_13_15 <= 16
#
# _C289: - u_14 + u_15 + 17 x_14_15 <= 16
#
# _C290: 0 u_15 + 17 x_15_15 <= 16
#
# _C291: u_15 - u_16 + 17 x_16_15 <= 16
#
# _C292: - u_1 + u_16 + 17 x_1_16 <= 16
#
# _C293: u_16 - u_2 + 17 x_2_16 <= 16
#
# _C294: u_16 - u_3 + 17 x_3_16 <= 16
#
# _C295: u_16 - u_4 + 17 x_4_16 <= 16
#
# _C296: u_16 - u_5 + 17 x_5_16 <= 16
#
# _C297: u_16 - u_6 + 17 x_6_16 <= 16
#
# _C298: u_16 - u_7 + 17 x_7_16 <= 16
#
# _C299: u_16 - u_8 + 17 x_8_16 <= 16
#
# _C300: u_16 - u_9 + 17 x_9_16 <= 16
#
# _C301: - u_10 + u_16 + 17 x_10_16 <= 16
#
# _C302: - u_11 + u_16 + 17 x_11_16 <= 16
#
# _C303: - u_12 + u_16 + 17 x_12_16 <= 16
#
# _C304: - u_13 + u_16 + 17 x_13_16 <= 16
#
# _C305: - u_14 + u_16 + 17 x_14_16 <= 16
#
# _C306: - u_15 + u_16 + 17 x_15_16 <= 16
#
# _C307: 0 u_16 + 17 x_16_16 <= 16
#
# VARIABLES
# 2 <= u_1 <= 17 Integer
# 2 <= u_10 <= 17 Integer
# 2 <= u_11 <= 17 Integer
# 2 <= u_12 <= 17 Integer
# 2 <= u_13 <= 17 Integer
# 2 <= u_14 <= 17 Integer
# 2 <= u_15 <= 17 Integer
# 2 <= u_16 <= 17 Integer
# 2 <= u_2 <= 17 Integer
# 2 <= u_3 <= 17 Integer
# 2 <= u_4 <= 17 Integer
# 2 <= u_5 <= 17 Integer
# 2 <= u_6 <= 17 Integer
# 2 <= u_7 <= 17 Integer
# 2 <= u_8 <= 17 Integer
# 2 <= u_9 <= 17 Integer
# 0 <= x_0_0 <= 1 Integer
# 0 <= x_0_1 <= 1 Integer
# 0 <= x_0_10 <= 1 Integer
# 0 <= x_0_11 <= 1 Integer
# 0 <= x_0_12 <= 1 Integer
# 0 <= x_0_13 <= 1 Integer
# 0 <= x_0_14 <= 1 Integer
# 0 <= x_0_15 <= 1 Integer
# 0 <= x_0_16 <= 1 Integer
# 0 <= x_0_2 <= 1 Integer
# 0 <= x_0_3 <= 1 Integer
# 0 <= x_0_4 <= 1 Integer
# 0 <= x_0_5 <= 1 Integer
# 0 <= x_0_6 <= 1 Integer
# 0 <= x_0_7 <= 1 Integer
# 0 <= x_0_8 <= 1 Integer
# 0 <= x_0_9 <= 1 Integer
# 0 <= x_10_0 <= 1 Integer
# 0 <= x_10_1 <= 1 Integer
# 0 <= x_10_10 <= 1 Integer
# 0 <= x_10_11 <= 1 Integer
# 0 <= x_10_12 <= 1 Integer
# 0 <= x_10_13 <= 1 Integer
# 0 <= x_10_14 <= 1 Integer
# 0 <= x_10_15 <= 1 Integer
# 0 <= x_10_16 <= 1 Integer
# 0 <= x_10_2 <= 1 Integer
# 0 <= x_10_3 <= 1 Integer
# 0 <= x_10_4 <= 1 Integer
# 0 <= x_10_5 <= 1 Integer
# 0 <= x_10_6 <= 1 Integer
# 0 <= x_10_7 <= 1 Integer
# 0 <= x_10_8 <= 1 Integer
# 0 <= x_10_9 <= 1 Integer
# 0 <= x_11_0 <= 1 Integer
# 0 <= x_11_1 <= 1 Integer
# 0 <= x_11_10 <= 1 Integer
# 0 <= x_11_11 <= 1 Integer
# 0 <= x_11_12 <= 1 Integer
# 0 <= x_11_13 <= 1 Integer
# 0 <= x_11_14 <= 1 Integer
# 0 <= x_11_15 <= 1 Integer
# 0 <= x_11_16 <= 1 Integer
# 0 <= x_11_2 <= 1 Integer
# 0 <= x_11_3 <= 1 Integer
# 0 <= x_11_4 <= 1 Integer
# 0 <= x_11_5 <= 1 Integer
# 0 <= x_11_6 <= 1 Integer
# 0 <= x_11_7 <= 1 Integer
# 0 <= x_11_8 <= 1 Integer
# 0 <= x_11_9 <= 1 Integer
# 0 <= x_12_0 <= 1 Integer
# 0 <= x_12_1 <= 1 Integer
# 0 <= x_12_10 <= 1 Integer
# 0 <= x_12_11 <= 1 Integer
# 0 <= x_12_12 <= 1 Integer
# 0 <= x_12_13 <= 1 Integer
# 0 <= x_12_14 <= 1 Integer
# 0 <= x_12_15 <= 1 Integer
# 0 <= x_12_16 <= 1 Integer
# 0 <= x_12_2 <= 1 Integer
# 0 <= x_12_3 <= 1 Integer
# 0 <= x_12_4 <= 1 Integer
# 0 <= x_12_5 <= 1 Integer
# 0 <= x_12_6 <= 1 Integer
# 0 <= x_12_7 <= 1 Integer
# 0 <= x_12_8 <= 1 Integer
# 0 <= x_12_9 <= 1 Integer
# 0 <= x_13_0 <= 1 Integer
# 0 <= x_13_1 <= 1 Integer
# 0 <= x_13_10 <= 1 Integer
# 0 <= x_13_11 <= 1 Integer
# 0 <= x_13_12 <= 1 Integer
# 0 <= x_13_13 <= 1 Integer
# 0 <= x_13_14 <= 1 Integer
# 0 <= x_13_15 <= 1 Integer
# 0 <= x_13_16 <= 1 Integer
# 0 <= x_13_2 <= 1 Integer
# 0 <= x_13_3 <= 1 Integer
# 0 <= x_13_4 <= 1 Integer
# 0 <= x_13_5 <= 1 Integer
# 0 <= x_13_6 <= 1 Integer
# 0 <= x_13_7 <= 1 Integer
# 0 <= x_13_8 <= 1 Integer
# 0 <= x_13_9 <= 1 Integer
# 0 <= x_14_0 <= 1 Integer
# 0 <= x_14_1 <= 1 Integer
# 0 <= x_14_10 <= 1 Integer
# 0 <= x_14_11 <= 1 Integer
# 0 <= x_14_12 <= 1 Integer
# 0 <= x_14_13 <= 1 Integer
# 0 <= x_14_14 <= 1 Integer
# 0 <= x_14_15 <= 1 Integer
# 0 <= x_14_16 <= 1 Integer
# 0 <= x_14_2 <= 1 Integer
# 0 <= x_14_3 <= 1 Integer
# 0 <= x_14_4 <= 1 Integer
# 0 <= x_14_5 <= 1 Integer
# 0 <= x_14_6 <= 1 Integer
# 0 <= x_14_7 <= 1 Integer
# 0 <= x_14_8 <= 1 Integer
# 0 <= x_14_9 <= 1 Integer
# 0 <= x_15_0 <= 1 Integer
# 0 <= x_15_1 <= 1 Integer
# 0 <= x_15_10 <= 1 Integer
# 0 <= x_15_11 <= 1 Integer
# 0 <= x_15_12 <= 1 Integer
# 0 <= x_15_13 <= 1 Integer
# 0 <= x_15_14 <= 1 Integer
# 0 <= x_15_15 <= 1 Integer
# 0 <= x_15_16 <= 1 Integer
# 0 <= x_15_2 <= 1 Integer
# 0 <= x_15_3 <= 1 Integer
# 0 <= x_15_4 <= 1 Integer
# 0 <= x_15_5 <= 1 Integer
# 0 <= x_15_6 <= 1 Integer
# 0 <= x_15_7 <= 1 Integer
# 0 <= x_15_8 <= 1 Integer
# 0 <= x_15_9 <= 1 Integer
# 0 <= x_16_0 <= 1 Integer
# 0 <= x_16_1 <= 1 Integer
# 0 <= x_16_10 <= 1 Integer
# 0 <= x_16_11 <= 1 Integer
# 0 <= x_16_12 <= 1 Integer
# 0 <= x_16_13 <= 1 Integer
# 0 <= x_16_14 <= 1 Integer
# 0 <= x_16_15 <= 1 Integer
# 0 <= x_16_16 <= 1 Integer
# 0 <= x_16_2 <= 1 Integer
# 0 <= x_16_3 <= 1 Integer
# 0 <= x_16_4 <= 1 Integer
# 0 <= x_16_5 <= 1 Integer
# 0 <= x_16_6 <= 1 Integer
# 0 <= x_16_7 <= 1 Integer
# 0 <= x_16_8 <= 1 Integer
# 0 <= x_16_9 <= 1 Integer
# 0 <= x_1_0 <= 1 Integer
# 0 <= x_1_1 <= 1 Integer
# 0 <= x_1_10 <= 1 Integer
# 0 <= x_1_11 <= 1 Integer
# 0 <= x_1_12 <= 1 Integer
# 0 <= x_1_13 <= 1 Integer
# 0 <= x_1_14 <= 1 Integer
# 0 <= x_1_15 <= 1 Integer
# 0 <= x_1_16 <= 1 Integer
# 0 <= x_1_2 <= 1 Integer
# 0 <= x_1_3 <= 1 Integer
# 0 <= x_1_4 <= 1 Integer
# 0 <= x_1_5 <= 1 Integer
# 0 <= x_1_6 <= 1 Integer
# 0 <= x_1_7 <= 1 Integer
# 0 <= x_1_8 <= 1 Integer
# 0 <= x_1_9 <= 1 Integer
# 0 <= x_2_0 <= 1 Integer
# 0 <= x_2_1 <= 1 Integer
# 0 <= x_2_10 <= 1 Integer
# 0 <= x_2_11 <= 1 Integer
# 0 <= x_2_12 <= 1 Integer
# 0 <= x_2_13 <= 1 Integer
# 0 <= x_2_14 <= 1 Integer
# 0 <= x_2_15 <= 1 Integer
# 0 <= x_2_16 <= 1 Integer
# 0 <= x_2_2 <= 1 Integer
# 0 <= x_2_3 <= 1 Integer
# 0 <= x_2_4 <= 1 Integer
# 0 <= x_2_5 <= 1 Integer
# 0 <= x_2_6 <= 1 Integer
# 0 <= x_2_7 <= 1 Integer
# 0 <= x_2_8 <= 1 Integer
# 0 <= x_2_9 <= 1 Integer
# 0 <= x_3_0 <= 1 Integer
# 0 <= x_3_1 <= 1 Integer
# 0 <= x_3_10 <= 1 Integer
# 0 <= x_3_11 <= 1 Integer
# 0 <= x_3_12 <= 1 Integer
# 0 <= x_3_13 <= 1 Integer
# 0 <= x_3_14 <= 1 Integer
# 0 <= x_3_15 <= 1 Integer
# 0 <= x_3_16 <= 1 Integer
# 0 <= x_3_2 <= 1 Integer
# 0 <= x_3_3 <= 1 Integer
# 0 <= x_3_4 <= 1 Integer
# 0 <= x_3_5 <= 1 Integer
# 0 <= x_3_6 <= 1 Integer
# 0 <= x_3_7 <= 1 Integer
# 0 <= x_3_8 <= 1 Integer
# 0 <= x_3_9 <= 1 Integer
# 0 <= x_4_0 <= 1 Integer
# 0 <= x_4_1 <= 1 Integer
# 0 <= x_4_10 <= 1 Integer
# 0 <= x_4_11 <= 1 Integer
# 0 <= x_4_12 <= 1 Integer
# 0 <= x_4_13 <= 1 Integer
# 0 <= x_4_14 <= 1 Integer
# 0 <= x_4_15 <= 1 Integer
# 0 <= x_4_16 <= 1 Integer
# 0 <= x_4_2 <= 1 Integer
# 0 <= x_4_3 <= 1 Integer
# 0 <= x_4_4 <= 1 Integer
# 0 <= x_4_5 <= 1 Integer
# 0 <= x_4_6 <= 1 Integer
# 0 <= x_4_7 <= 1 Integer
# 0 <= x_4_8 <= 1 Integer
# 0 <= x_4_9 <= 1 Integer
# 0 <= x_5_0 <= 1 Integer
# 0 <= x_5_1 <= 1 Integer
# 0 <= x_5_10 <= 1 Integer
# 0 <= x_5_11 <= 1 Integer
# 0 <= x_5_12 <= 1 Integer
# 0 <= x_5_13 <= 1 Integer
# 0 <= x_5_14 <= 1 Integer
# 0 <= x_5_15 <= 1 Integer
# 0 <= x_5_16 <= 1 Integer
# 0 <= x_5_2 <= 1 Integer
# 0 <= x_5_3 <= 1 Integer
# 0 <= x_5_4 <= 1 Integer
# 0 <= x_5_5 <= 1 Integer
# 0 <= x_5_6 <= 1 Integer
# 0 <= x_5_7 <= 1 Integer
# 0 <= x_5_8 <= 1 Integer
# 0 <= x_5_9 <= 1 Integer
# 0 <= x_6_0 <= 1 Integer
# 0 <= x_6_1 <= 1 Integer
# 0 <= x_6_10 <= 1 Integer
# 0 <= x_6_11 <= 1 Integer
# 0 <= x_6_12 <= 1 Integer
# 0 <= x_6_13 <= 1 Integer
# 0 <= x_6_14 <= 1 Integer
# 0 <= x_6_15 <= 1 Integer
# 0 <= x_6_16 <= 1 Integer
# 0 <= x_6_2 <= 1 Integer
# 0 <= x_6_3 <= 1 Integer
# 0 <= x_6_4 <= 1 Integer
# 0 <= x_6_5 <= 1 Integer
# 0 <= x_6_6 <= 1 Integer
# 0 <= x_6_7 <= 1 Integer
# 0 <= x_6_8 <= 1 Integer
# 0 <= x_6_9 <= 1 Integer
# 0 <= x_7_0 <= 1 Integer
# 0 <= x_7_1 <= 1 Integer
# 0 <= x_7_10 <= 1 Integer
# 0 <= x_7_11 <= 1 Integer
# 0 <= x_7_12 <= 1 Integer
# 0 <= x_7_13 <= 1 Integer
# 0 <= x_7_14 <= 1 Integer
# 0 <= x_7_15 <= 1 Integer
# 0 <= x_7_16 <= 1 Integer
# 0 <= x_7_2 <= 1 Integer
# 0 <= x_7_3 <= 1 Integer
# 0 <= x_7_4 <= 1 Integer
# 0 <= x_7_5 <= 1 Integer
# 0 <= x_7_6 <= 1 Integer
# 0 <= x_7_7 <= 1 Integer
# 0 <= x_7_8 <= 1 Integer
# 0 <= x_7_9 <= 1 Integer
# 0 <= x_8_0 <= 1 Integer
# 0 <= x_8_1 <= 1 Integer
# 0 <= x_8_10 <= 1 Integer
# 0 <= x_8_11 <= 1 Integer
# 0 <= x_8_12 <= 1 Integer
# 0 <= x_8_13 <= 1 Integer
# 0 <= x_8_14 <= 1 Integer
# 0 <= x_8_15 <= 1 Integer
# 0 <= x_8_16 <= 1 Integer
# 0 <= x_8_2 <= 1 Integer
# 0 <= x_8_3 <= 1 Integer
# 0 <= x_8_4 <= 1 Integer
# 0 <= x_8_5 <= 1 Integer
# 0 <= x_8_6 <= 1 Integer
# 0 <= x_8_7 <= 1 Integer
# 0 <= x_8_8 <= 1 Integer
# 0 <= x_8_9 <= 1 Integer
# 0 <= x_9_0 <= 1 Integer
# 0 <= x_9_1 <= 1 Integer
# 0 <= x_9_10 <= 1 Integer
# 0 <= x_9_11 <= 1 Integer
# 0 <= x_9_12 <= 1 Integer
# 0 <= x_9_13 <= 1 Integer
# 0 <= x_9_14 <= 1 Integer
# 0 <= x_9_15 <= 1 Integer
# 0 <= x_9_16 <= 1 Integer
# 0 <= x_9_2 <= 1 Integer
# 0 <= x_9_3 <= 1 Integer
# 0 <= x_9_4 <= 1 Integer
# 0 <= x_9_5 <= 1 Integer
# 0 <= x_9_6 <= 1 Integer
# 0 <= x_9_7 <= 1 Integer
# 0 <= x_9_8 <= 1 Integer
# 0 <= x_9_9 <= 1 Integer
#
# the minimal cycle length is  1362.4876183927852
# [15, 6, 9, 7, 4, 12, 3, 14, 5, 8, 13, 1, 16, 10, 11, 2, 0]
